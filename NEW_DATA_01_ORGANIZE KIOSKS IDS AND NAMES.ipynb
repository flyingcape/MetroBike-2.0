# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 20})

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Load MetroBike "trips" Dataset

# %%
# CSV downloaded Dec 20, 2022
trips = pd.read_csv('../data/data_austintexas_gov/Austin_MetroBike_Trips_new2.csv')
# Out:
# /Users/flyingcape/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
trips.head()
# Out:
#       Trip ID                     Membership Type Bicycle ID  Bike Type  \
# 0  9900285854        Annual (San Antonio B-cycle)      207.0        NaN
# 1  9900285855      24-Hour Kiosk (Austin B-cycle)      969.0        NaN
# 2  9900285856  Annual Membership (Austin B-cycle)      214.0        NaN
# 3  9900285857      24-Hour Kiosk (Austin B-cycle)      745.0        NaN
# 4  9900285858      24-Hour Kiosk (Austin B-cycle)      164.0        NaN
#
#   Checkout Date Checkout Time  Checkout Kiosk ID  \
# 0    10/26/2014      13:12:00             2537.0
# 1    10/26/2014      13:12:00             2498.0
# 2    10/26/2014      13:12:00             2537.0
# 3    10/26/2014      13:12:00                NaN
# 4    10/26/2014      13:12:00             2538.0
#
#                                       Checkout Kiosk Return Kiosk ID  \
# 0                                     West & 6th St.          2707.0
# 1            Convention Center / 4th St. @ MetroRail          2566.0
# 2                                     West & 6th St.          2496.0
# 3  Zilker Park at Barton Springs & William Barton...             NaN
# 4                    Bullock Museum @ Congress & MLK             NaN
#
#                                         Return Kiosk  Trip Duration Minutes  \
# 0                               Rainey St @ Cummings                     76
# 1                      Pfluger Bridge @ W 2nd Street                     58
# 2                                     8th & Congress                      8
# 3  Zilker Park at Barton Springs & William Barton...                     28
# 4                   Convention Center/ 3rd & Trinity                     15
#
#    Month    Year
# 0   10.0  2014.0
# 1   10.0  2014.0
# 2   10.0  2014.0
# 3   10.0  2014.0
# 4   10.0  2014.0

# %%
# check number of rows/trips
trips.shape[0]
# Out:
# 1847746

# %%
trips.dtypes
# Out:
# Trip ID                    int64
# Membership Type           object
# Bicycle ID                object
# Bike Type                float64
# Checkout Date             object
# Checkout Time             object
# Checkout Kiosk ID        float64
# Checkout Kiosk            object
# Return Kiosk ID           object
# Return Kiosk              object
# Trip Duration Minutes      int64
# Month                    float64
# Year                     float64
# dtype: object

# %%
# Adjusting the Return Kiosk ID to float 64
# however, on label is a string, so changing it to nan
trips.loc[trips['Return Kiosk ID']=="Event",'Return Kiosk ID'] = np.nan
trips['Return Kiosk ID'] = trips['Return Kiosk ID'].astype(float)

# %%
trips.dtypes
# Out:
# Trip ID                    int64
# Membership Type           object
# Bicycle ID                object
# Bike Type                float64
# Checkout Date             object
# Checkout Time             object
# Checkout Kiosk ID        float64
# Checkout Kiosk            object
# Return Kiosk ID          float64
# Return Kiosk              object
# Trip Duration Minutes      int64
# Month                    float64
# Year                     float64
# dtype: object

# %% [markdown]
# # Load "kiosk" Dataset

# %%
# CSV downloaded Dec 20, 2022
kiosk = pd.read_csv('../data/data_austintexas_gov/Austin_MetroBike_Kiosk_Locations_new2.csv')

# %%
kiosk.head()
# Out:
#    Kiosk ID                               Kiosk Name Kiosk Status  \
# 0      2823  Capital Metro HQ - East 5th at Broadway       active
# 1      3291                       11th & San Jacinto       active
# 2      3292                        East 4th & Chicon       active
# 3      3293                    East 2nd & Pedernales       active
# 4      3294                             Lavaca & 6th       active
#
#                   Location            Address Alternate Name  \
# 0     (30.2563, -97.71007)      2910 E 5th St            NaN
# 1    (30.27193, -97.73854)    310 E. 11th St.            NaN
# 2    (30.25987, -97.72373)  1819 East 4th St.            NaN
# 3    (30.25542, -97.71665)      2414 E 2nd St            NaN
# 4  (30.268887, -97.745242)     601 Lavaca St.            NaN
#
#    City Asset Number         Property Type  Number of Docks Power Type  \
# 0            16684.0  undetermined_parking             13.0      solar
# 1            32503.0              sidewalk             11.0      solar
# 2            32516.0  undetermined_parking              9.0      solar
# 3            16729.0    nonmetered_parking             10.0      solar
# 4            32515.0              sidewalk             12.0      solar
#
#    Footprint Length  Footprint Width  \
# 0              40.0              5.0
# 1              35.0              5.0
# 2              30.0              5.0
# 3              20.0             15.0
# 4              25.0              8.0
#
#                                                Notes  Council District  Image  \
# 0                                                NaN                 3    NaN
# 1                                                NaN                 1    NaN
# 2                                                NaN                 3    NaN
# 3  Kiosk replaced by Barton Sp/Riverside.  Old ci...                 3    NaN
# 4                            double sided, remeasure                 9    NaN
#
#             Modified Date
# 0  01/04/2021 12:00:00 AM
# 1  01/04/2021 12:00:00 AM
# 2  01/04/2021 12:00:00 AM
# 3  01/04/2021 12:00:00 AM
# 4  03/04/2022 10:21:00 AM

# %%
# check number of rows/kiosk locations
kiosk.shape[0]
# Out:
# 102

# %%
kiosk.dtypes
# Out:
# Kiosk ID               int64
# Kiosk Name            object
# Kiosk Status          object
# Location              object
# Address               object
# Alternate Name        object
# City Asset Number    float64
# Property Type         object
# Number of Docks      float64
# Power Type            object
# Footprint Length     float64
# Footprint Width      float64
# Notes                 object
# Council District       int64
# Image                float64
# Modified Date         object
# dtype: object

# %% [markdown]
# # Data Cleaning Begins..

# %% [markdown]
# ## 1. Remove trips that are "too short" or "too long"

# %% [markdown]
# Note: Plotting and checking out the Trip Duration data, but ultimately REMOVING THE SHORT TRIPS (0 MINUTES) and TRIPS LONGER THAN X DAYS (see next cell) in later cells

# %%
# Removing trips that are longer than this upper limit
upplim = 5760 # duration in minutes
print(upplim*(1/60)*(1/24)," days") # printing the limit in days units
# Out:
# 4.0  days

# %%
trips['Trip Duration Minutes'].describe()
# Out:
# count    1.847746e+06
# mean     2.982984e+01
# std      1.267121e+02
# min      0.000000e+00
# 25%      6.000000e+00
# 50%      1.200000e+01
# 75%      2.800000e+01
# max      3.423800e+04
# Name: Trip Duration Minutes, dtype: float64

# %%
plt.boxplot(trips['Trip Duration Minutes'])
# some of the trips are too short (0 minutues) 
# and potentially too long 
# removing these trips
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ffae9739130>,
#   <matplotlib.lines.Line2D at 0x7ffae9739490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffae97397f0>,
#   <matplotlib.lines.Line2D at 0x7ffae9739b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ffac9e33d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffae9739eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffae9745250>],
#  'means': []}

# %%
plt.hist(trips['Trip Duration Minutes'], bins = 5000)
plt.xlim(0,500)
# Out:
# (0.0, 500.0)

# %%
start_trips = trips.shape[0]
print(trips.shape[0])
# Out:
# 1847746

# %% [markdown]
# REMOVING THE SHORT TRIPS (0 MINUTES) and TRIPS LONGER THAN X DAYS

# %%
trips = trips[(trips['Trip Duration Minutes']>0) & (trips['Trip Duration Minutes']<=upplim)]

# %% [markdown]
# Lets look at the data after this change

# %%
after_trips = trips.shape[0]
print(trips.shape[0])
# Out:
# 1825892

# %%
print("Removed: ",start_trips-after_trips)
print("Percent Removed",round(((start_trips-after_trips)/start_trips)*100,2)," %")
# Out:
# Removed:  21854
# Percent Removed 1.18  %

# %%
# replotting
plt.boxplot(trips['Trip Duration Minutes'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ffade9cf700>,
#   <matplotlib.lines.Line2D at 0x7ffade9cfa60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffade9cfdc0>,
#   <matplotlib.lines.Line2D at 0x7ffade9dc160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ffade9cf3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffade9dc4c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffade9dc820>],
#  'means': []}

# %%
plt.hist(trips['Trip Duration Minutes'], bins = 5000)
plt.xlim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# ## 2. Removing these trip rows, based on the checkout kiosk name, the trips appear to be maintenance-related trips

# %%
# remove blank spaces at start and end 
trips['Checkout Kiosk'] = trips['Checkout Kiosk'].str.strip()
trips['Return Kiosk'] = trips['Return Kiosk'].str.strip()
kiosk['Kiosk Name'] = kiosk['Kiosk Name'].str.strip()

# %%
# Checkout Kiosk
trips = trips.loc[trips['Checkout Kiosk'] != 'Customer Service']
trips = trips.loc[trips['Checkout Kiosk'] != 'Re-branding']
trips = trips.loc[trips['Checkout Kiosk'] != 'Repair Shop']
trips = trips.loc[trips['Checkout Kiosk'] != 'Shop']
trips = trips.loc[trips['Checkout Kiosk'] != 'Main Office'] # Probably testing 
trips = trips.loc[trips['Checkout Kiosk'] != 'Stolen'] # removing these too

# %%
# There are some Missing and Stolen, but NOT removing them - because I want to count those checkouts as trips...
# even if they are not returned properly..

# Return Kiosk
#trips = trips.loc[trips['Checkout Kiosk'] != 'Stolen'] # removing these too
#trips = trips.loc[trips['Checkout Kiosk'] != 'Stolen'] # removing these too

# %% [markdown]
# ## 3. Creating a Dataframe of the Kiosk Names and the last ID used

# %% [markdown]
# Adding Checkout DateTime & Return DateTime columns

# %%
# Creating a Checkout DateTime column to combine the Date and Time columns
trips["Checkout DateTime"] = trips["Checkout Date"] + " " + trips["Checkout Time"]

# %%
# Converting to DateTime type
# Need this so max and min functions work correctly
trips["Checkout DateTime"] = pd.to_datetime(trips["Checkout DateTime"])

# %%
# Calculating a Return DateTime column
from datetime import datetime, timedelta
return_datetime = []
# for loop because I couldn't sent in a series into the timedelta function...
for start_time, delta_time in zip(trips["Checkout DateTime"], trips["Trip Duration Minutes"]):
    return_datetime.append(start_time + timedelta(minutes=delta_time))
        
trips["Return DateTime"] = return_datetime

# %%
trips.dtypes
# Out:
# Trip ID                           int64
# Membership Type                  object
# Bicycle ID                       object
# Bike Type                       float64
# Checkout Date                    object
# Checkout Time                    object
# Checkout Kiosk ID               float64
# Checkout Kiosk                   object
# Return Kiosk ID                 float64
# Return Kiosk                     object
# Trip Duration Minutes             int64
# Month                           float64
# Year                            float64
# Checkout DateTime        datetime64[ns]
# Return DateTime          datetime64[ns]
# dtype: object

# %% [markdown]
# Retrieving a list of all the KIOSK NAMES

# %%
# Retrieving a list of all the kiosk names..
all_names = sorted(np.unique(np.concatenate((trips['Checkout Kiosk'].unique() , trips['Return Kiosk'].unique()))))
print('first 5...')
print(all_names[0:5], "\n")

# Removing the temporary/non-permanent & maintenance kiosk names from this list
names2remove = ['ACL 2019 Drop Off', 'Earth Day ATX 2017', "Eeyore's 2017", "Eeyore's 2018", 
                  'Fantasy Zilker', 'MapJam at French Legation', 'MapJam at Hops & Grain Brewery', 
                  'MapJam at Pan Am Park', 'MapJam at Scoot Inn', 'Marketing Event', 'Mobile Station', 
                  'Mobile Station @ Bike Fest', 'Mobile Station @ Boardwalk Opening Ceremony', 
                  'Mobile Station @ Unplugged', 'Springfest 2022',
                 'Customer Service', 'Main Office', 'Main Shop', 'Missing', 'Repair Shop', 'Shop', 'Stolen']
print("names to REMOVE:\n ", names2remove, "\n")

for remove_name in names2remove:
    all_names.remove(remove_name)
# Out:
# first 5...
# ['10th & Red River', '10th/Red River', '11th & Salina', '11th & San Jacinto', '11th/Congress @ The Texas Capitol']
#
# names to REMOVE:
#   ['ACL 2019 Drop Off', 'Earth Day ATX 2017', "Eeyore's 2017", "Eeyore's 2018", 'Fantasy Zilker', 'MapJam at French Legation', 'MapJam at Hops & Grain Brewery', 'MapJam at Pan Am Park', 'MapJam at Scoot Inn', 'Marketing Event', 'Mobile Station', 'Mobile Station @ Bike Fest', 'Mobile Station @ Boardwalk Opening Ceremony', 'Mobile Station @ Unplugged', 'Springfest 2022', 'Customer Service', 'Main Office', 'Main Shop', 'Missing', 'Repair Shop', 'Shop', 'Stolen']

# %% [markdown]
# Build the DATAFRAME with historical information on names used, when, & ID numbers..

# %%
# Loop through each kiosk name and build a dataframe (LARGE DATAFRAME)
# of information regarding when that name was used and what the kiosk ID was 
name_dates_ids = pd.DataFrame(columns=['Kiosk Name','First Date Used','Last Date Used','First ID','Last ID'])

for name_test in all_names:
    # subsets of trips    
    trips_set_checkout = trips.loc[(trips["Checkout Kiosk"] == name_test)&(trips["Checkout Kiosk ID"].notnull())]
    trips_set_return = trips.loc[(trips["Return Kiosk"] == name_test)&(trips["Return Kiosk ID"].notnull())]
    
    #print(name_test)    
    # ---------------
    # First Date
    # ---------------
    first_date_checkout = trips_set_checkout["Checkout DateTime"].min()
    first_date_return = trips_set_return["Return DateTime"].min()
    first_date = min([first_date_checkout,first_date_return])

    checkout_ID_first = trips_set_checkout.loc[(trips_set_checkout["Checkout DateTime"] == first_date) & 
          (trips_set_checkout["Checkout Kiosk"] == name_test),"Checkout Kiosk ID"]
    return_ID_first = trips_set_return.loc[(trips_set_return["Return DateTime"] == first_date) & 
          (trips_set_return["Return Kiosk"] == name_test),"Return Kiosk ID"]

    if not checkout_ID_first.empty:
        kiosk_id_first = checkout_ID_first.tolist()[0]
        kiosk_type_first = "checkout"
    elif not return_ID_first.empty:
        kiosk_id_first = return_ID_first.tolist()[0]
        kiosk_type_first = "return"

    #print("First Date this ID appeared:", first_date)
    #print(kiosk_id_first)
    #print(kiosk_type_first)

    # ---------------
    # Last Date
    # ---------------
    last_date_checkout = trips_set_checkout["Checkout DateTime"].max()
    last_date_return = trips_set_return["Return DateTime"].max()
    last_date = max([last_date_checkout,last_date_return])

    checkout_ID_last = trips_set_checkout.loc[(trips_set_checkout["Checkout DateTime"] == last_date) & 
          (trips_set_checkout["Checkout Kiosk"] == name_test),"Checkout Kiosk ID"]

    return_ID_last = trips_set_return.loc[(trips_set_return["Return DateTime"] == last_date) & 
          (trips_set_return["Return Kiosk"] == name_test),"Return Kiosk ID"]

    if not checkout_ID_last.empty:
        kiosk_id_last = checkout_ID_last.tolist()[0]
        kiosk_type_last = "checkout"
    elif not return_ID_last.empty:
        kiosk_id_last = return_ID_last.tolist()[0]
        kiosk_type_last = "return"

    #print("Last Date this ID appeared:", last_date)
    #print(kiosk_id_last)
    #print(kiosk_type_last)
    
    # ------------------------------------------------------------------------------------
    # SPECIAL CASES where IDs are all null & result in the dates being null in above code
    if (first_date is pd.NaT) | (last_date is pd.NaT):
        tcheckout = trips.loc[(trips["Checkout Kiosk"] == name_test)]
        treturn = trips.loc[(trips["Return Kiosk"] == name_test)]
        
        first_date_checkout = tcheckout["Checkout DateTime"].min()
        first_date_return = treturn["Return DateTime"].min()
        first_date = min([first_date_checkout,first_date_return])
    
        last_date_checkout = tcheckout["Checkout DateTime"].max()
        last_date_return = treturn["Return DateTime"].max()
        last_date = max([last_date_checkout,last_date_return])   
        
    # ------------------------------------------------------------------------------------
    
    new_row = {'Kiosk Name': name_test, 'First Date Used': first_date.date(), 'Last Date Used': last_date.date(), 
           'First ID': kiosk_id_first,'Last ID': kiosk_id_last}
    name_dates_ids = name_dates_ids.append(new_row, ignore_index=True)
       
    first_date = np.nan
    last_date = np.nan
    kiosk_id_first = np.nan
    kiosk_id_last = np.nan

# %%
name_dates_ids
# Out:
#                                             Kiosk Name First Date Used  \
# 0                                     10th & Red River      2018-08-15
# 1                                       10th/Red River      2019-06-01
# 2                                        11th & Salina      2018-08-16
# 3                                   11th & San Jacinto      2015-08-12
# 4                    11th/Congress @ The Texas Capitol      2019-06-01
# 5                                          11th/Salina      2019-06-03
# 6                                     11th/San Jacinto      2019-06-01
# 7     12th/San Jacinto @ State Capitol Visitors Garage      2019-06-01
# 8                                   13th & San Antonio      2017-02-21
# 9                                     13th/San Antonio      2019-06-02
# 10                                        13th/Trinity      2021-10-01
# 11                    13th/Trinity @ Waterloo Greenway      2022-04-01
# 12                                    16th/San Antonio      2021-01-23
# 13                                    17th & Guadalupe      2014-01-30
# 14                                      17th/Guadalupe      2019-06-01
# 15                                21st & Speedway @PCL      2018-02-02
# 16                                   21st & University      2018-01-31
# 17                                      21st/Guadalupe      2019-06-01
# 18                                 21st/Speedway @ PCL      2019-06-01
# 19                                     21st/University      2019-06-01
# 20                                     22.5/Rio Grande      2021-04-08
# 21                                        22nd & Pearl      2018-01-30
# 22                                          22nd/Pearl      2019-06-01
# 23                                   23rd & Rio Grande      2018-02-01
# 24                    23rd & San Jacinto @ DKR Stadium      2018-02-02
# 25                                          23rd/Pearl      2022-06-01
# 26                                     23rd/Rio Grande      2019-06-02
# 27                                    23rd/San Gabriel      2021-10-01
# 28                      23rd/San Jacinto @ DKR Stadium      2019-06-01
# 29                                         26th/Nueces      2019-06-01
# 30                                            28th/Rio      2022-04-07
# 31                                     28th/Rio Grande      2019-06-01
# 32                                      2nd & Congress      2013-12-21
# 33                                        2nd/Congress      2019-06-01
# 34                              2nd/Lavaca @ City Hall      2019-06-01
# 35                                          3rd & West      2014-02-04
# 36                                          3rd/Nueces      2019-06-01
# 37                 3rd/Trinity @ The Convention Center      2019-06-01
# 38                                            3rd/West      2019-06-01
# 39                                      4th & Congress      2013-12-21
# 40                                        4th/Congress      2019-06-01
# 41                     4th/Guadalupe @ Republic Square      2019-11-02
# 42                     4th/Neches @ MetroRail Downtown      2019-06-01
# 43                                          4th/Sabine      2020-03-08
# 44                                         5th & Bowie      2013-12-21
# 45                                      5th & Campbell      2018-08-20
# 46                                    5th & San Marcos      2014-02-28
# 47                                           5th/Bowie      2019-08-19
# 48                                        5th/Campbell      2019-06-01
# 49                     5th/Guadalupe @ Republic Square      2019-06-01
# 50                                      6th & Chalmers      2018-08-14
# 51                                      6th & Congress      2016-11-29
# 52                                  6th & Navasota St.      2014-01-29
# 53                                          6th/Brazos      2019-06-01
# 54                                        6th/Chalmers      2019-06-02
# 55                                        6th/Congress      2019-06-01
# 56                                          6th/Lavaca      2019-06-01
# 57                                         6th/Trinity      2019-06-01
# 58                                            6th/West      2019-06-02
# 59                                      8th & Congress      2013-12-21
# 60                                     8th & Guadalupe      2014-02-04
# 61                                        8th & Lavaca      2018-08-18
# 62                                        8th/Congress      2019-06-01
# 63                                          8th/Lavaca      2019-06-02
# 64                                       8th/Red River      2019-06-01
# 65                                     8th/San Jacinto      2019-06-02
# 66                                       9th/Henderson      2019-06-01
# 67                             ACC - Rio Grande & 12th      2014-01-31
# 68                                   ACC - West & 12th      2014-01-31
# 69                            ACC - West & 12th Street      2015-10-01
# 70                          Barton Springs & Riverside      2013-12-21
# 71                         Barton Springs @ Kinney Ave      2014-06-11
# 72                                 Barton Springs Pool      2014-02-27
# 73          Barton Springs/Bouldin @ Palmer Auditorium      2019-06-01
# 74                               Barton Springs/Kinney      2019-06-01
# 75                            Barton Springs/Riverside      2022-06-26
# 76                                      Boardwalk West      2017-05-16
# 77                                        Brazos & 6th      2016-02-19
# 78                     Bullock Museum @ Congress & MLK      2014-02-01
# 79             Capital Metro HQ - East 5th at Broadway      2014-09-16
# 80                   Capitol Station / Congress & 11th      2013-12-21
# 81                               Cesar Chavez/Congress      2019-06-01
# 82                            City Hall / Lavaca & 2nd      2013-12-21
# 83                             Congress & Cesar Chavez      2017-07-07
# 84                   Convention Center / 3rd & Trinity      2014-11-01
# 85             Convention Center / 4th St. @ MetroRail      2013-12-21
# 86                    Convention Center/ 3rd & Trinity      2014-06-13
# 87                              Davis at Rainey Street      2014-02-25
# 88                              Dean Keeton & Speedway      2018-01-29
# 89                                Dean Keeton & Whitis      2018-01-29
# 90                                Dean Keeton/Speedway      2019-06-01
# 91                                  Dean Keeton/Whitis      2019-06-02
# 92                          East 11th St. & San Marcos      2014-02-27
# 93                      East 11th St. at Victory Grill      2014-11-01
# 94                   East 11th Street at Victory Grill      2014-02-27
# 95                                East 11th/San Marcos      2019-06-02
# 96                             East 11th/Victory Grill      2019-06-01
# 97                               East 2nd & Pedernales      2015-08-15
# 98                                 East 2nd/Pedernales      2019-06-01
# 99                                   East 4th & Chicon      2015-08-13
# 100                                    East 4th/Chicon      2019-06-01
# 101               East 5th/Broadway @ Capital Metro HQ      2019-06-02
# 102                East 5th/Shady @ Eastside Bus Plaza      2021-01-05
# 103                                  East 5th/Shady Ln      2020-11-22
# 104                          East 6th & Pedernales St.      2014-07-01
# 105                        East 6th at Robert Martinez      2014-09-16
# 106                                    East 6th/Medina      2019-06-01
# 107                                East 6th/Pedernales      2019-07-26
# 108                        East 6th/Robert T. Martinez      2019-06-02
# 109                         East 7th & Pleasant Valley      2015-12-30
# 110  Electric Drive/Sandra Muraida Way @ Pfluger Pe...      2019-06-01
# 111                                   Guadalupe & 21st      2014-02-01
# 112                                    Guadalupe & 6th      2017-01-01
# 113             Guadalupe/West Mall @ University Co-op      2019-06-01
# 114                                    Henderson & 9th      2017-07-06
# 115                        Hollow Creek & Barton Hills      2018-08-21
# 116                          Hollow Creek/Barton Hills      2019-06-01
# 117                              Lake Austin & Enfield      2018-02-01
# 118                       Lake Austin Blvd @ Deep Eddy      2018-02-01
# 119                         Lake Austin Blvd/Deep Eddy      2019-06-01
# 120                                Lake Austin/Enfield      2019-06-21
# 121                        Lakeshore & Pleasant Valley      2018-08-18
# 122                          Lakeshore @ Austin Hostel      2018-08-16
# 123                            Lakeshore/Austin Hostel      2019-06-01
# 124                          Lakeshore/Pleasant Valley      2019-06-01
# 125                                       Lavaca & 6th      2015-08-12
# 126                Long Center @ South 1st & Riverside      2014-02-01
# 127                                  Medina & East 6th      2017-03-03
# 128           MoPac Pedestrian Bridge @ Veterans Drive      2015-12-19
# 129                         Nash Hernandez @ RBJ South      2018-08-18
# 130                    Nash Hernandez/East @ RBJ South      2019-06-01
# 131                                      Nueces & 26th      2018-01-30
# 132                                       Nueces & 3rd      2017-01-01
# 133                                       Nueces @ 3rd      2015-02-25
# 134                                   One Texas Center      2022-02-25
# 135                                  Palmer Auditorium      2014-02-24
# 136                                         Pease Park      2016-06-02
# 137                      Pfluger Bridge @ W 2nd Street      2014-02-28
# 138                                     Plaza Saltillo      2014-02-03
# 139                                  Rainey @ River St      2015-04-02
# 140                               Rainey St @ Cummings      2014-06-11
# 141                                    Rainey/Cummings      2019-06-01
# 142                                       Rainey/Davis      2019-06-02
# 143                                    Rainey/Driskill      2022-02-19
# 144                             Red River & 8th Street      2014-02-28
# 145                            Red River @ LBJ Library      2014-06-17
# 146              Red River/Cesar Chavez @ The Fairmont      2018-08-15
# 147                                    Republic Square      2013-12-21
# 148                  Republic Square @ 5th & Guadalupe      2017-09-01
# 149         Republic Square @ Federal Courthouse Plaza      2016-06-01
# 150              Republic Square @ Guadalupe & 4th St.      2014-02-03
# 151                                  Rio Grande & 28th      2018-01-30
# 152                                    Rio Grande/12th      2022-03-04
# 153                               Riverside @ S. Lamar      2014-02-26
# 154                              Riverside/South Lamar      2019-06-01
# 155                                Rosewood & Angelina      2018-08-15
# 156                                  Rosewood & Chicon      2018-08-16
# 157                                  Rosewood/Angelina      2019-06-11
# 158                                    Rosewood/Chicon      2019-06-04
# 159                           San Jacinto & 8th Street      2014-02-25
# 160                  South 1st/Riverside @ Long Center      2019-06-01
# 161                           South Congress & Academy      2014-02-24
# 162  South Congress & Barton Springs at the Austin ...      2016-07-12
# 163                         South Congress & Elizabeth      2013-12-21
# 164                             South Congress & James      2013-12-21
# 165                     South Congress @ Bouldin Creek      2018-08-20
# 166                             South Congress/Academy      2019-06-01
# 167  South Congress/Barton Springs @ The Austin Ame...      2019-06-01
# 168                           South Congress/Elizabeth      2019-06-01
# 169                               South Congress/James      2019-06-01
# 170                                South Congress/Mary      2022-02-25
# 171                    State Capitol @ 14th & Colorado      2014-01-31
# 172  State Capitol Visitors Garage @ San Jacinto & ...      2014-02-25
# 173               State Parking Garage @ Brazos & 18th      2014-01-31
# 174                         Sterzing at Barton Springs      2017-07-06
# 175                            Sterzing/Barton Springs      2019-06-01
# 176                            Toomey Rd @ South Lamar      2014-06-11
# 177                               Trinity & 6th Street      2014-02-28
# 178                           UT West Mall @ Guadalupe      2014-02-01
# 179                Veterans/Atlanta @ MoPac Ped Bridge      2019-06-01
# 180                                   Waller & 6th St.      2014-01-29
# 181                                     West & 6th St.      2014-01-29
# 182                                        Zilker Park      2015-09-01
# 183                                   Zilker Park West      2015-10-01
# 184  Zilker Park at Barton Springs & William Barton...      2014-02-27
# 185                              cesar Chavez/Congress      2019-12-14
#
#     Last Date Used  First ID  Last ID
# 0       2019-05-31    4051.0   4051.0
# 1       2022-11-30    4051.0   4051.0
# 2       2019-05-31    4055.0   4055.0
# 3       2019-05-31    3291.0   3291.0
# 4       2022-11-30    2497.0   2497.0
# 5       2022-11-30    4055.0   4055.0
# 6       2022-10-02    3291.0   3291.0
# 7       2022-11-30    2561.0   2561.0
# 8       2019-05-31    3635.0   3635.0
# 9       2020-11-18    3635.0   3635.0
# 10      2022-03-31    7131.0   7131.0
# 11      2022-11-30    7131.0   7131.0
# 12      2022-11-30    4879.0   4879.0
# 13      2019-05-31    2540.0   2540.0
# 14      2020-04-11    2540.0   2540.0
# 15      2019-05-31    3798.0   3798.0
# 16      2019-05-31    3797.0   3797.0
# 17      2022-11-30    2547.0   2547.0
# 18      2022-11-30    3798.0   3798.0
# 19      2022-11-30    3797.0   3797.0
# 20      2022-11-30    4938.0   4938.0
# 21      2019-05-31    3792.0   3792.0
# 22      2022-11-30    3792.0   7188.0
# 23      2019-05-31    3841.0   3841.0
# 24      2019-05-31    3799.0   3799.0
# 25      2022-11-30    7125.0   7125.0
# 26      2021-09-28    3841.0   3841.0
# 27      2022-05-31    7125.0   7125.0
# 28      2022-11-30    3799.0   3799.0
# 29      2022-11-30    3838.0   3838.0
# 30      2022-11-30    7189.0   7189.0
# 31      2022-02-22    3793.0   3793.0
# 32      2019-05-31    2494.0   2494.0
# 33      2022-11-30    2494.0   2494.0
# 34      2022-11-30    2499.0   2499.0
# 35      2019-05-31    2552.0   2552.0
# 36      2022-11-30    3621.0   3621.0
# 37      2022-11-30    2539.0   2539.0
# 38      2022-11-30    2552.0   2552.0
# 39      2019-05-31    2495.0   2495.0
# 40      2022-11-30    2495.0   2495.0
# 41      2022-11-30    3455.0   3455.0
# 42      2019-06-20    2498.0   2498.0
# 43      2022-11-29    3794.0   3794.0
# 44      2019-05-29    2501.0   2501.0
# 45      2019-05-31    4050.0   4050.0
# 46      2017-03-03    2564.0   2564.0
# 47      2022-11-30    2501.0   2501.0
# 48      2022-11-30    4050.0   4050.0
# 49      2019-10-31    3455.0   3455.0
# 50      2019-05-31    4057.0   4057.0
# 51      2019-05-31    3619.0   3619.0
# 52      2014-06-30    1002.0   1002.0
# 53      2022-11-30    3390.0   3390.0
# 54      2022-11-30    4057.0   4057.0
# 55      2022-11-30    3619.0   3619.0
# 56      2022-11-30    3294.0   3294.0
# 57      2022-11-30    2565.0   2565.0
# 58      2022-11-29    2537.0   2537.0
# 59      2019-05-31    2496.0   2496.0
# 60      2014-06-12    1003.0   1003.0
# 61      2019-05-31    4047.0   4047.0
# 62      2022-11-29    2496.0   2496.0
# 63      2022-11-30    4047.0   4047.0
# 64      2022-11-30    2571.0   2571.0
# 65      2022-11-30    2562.0   2562.0
# 66      2022-11-30    3685.0   3685.0
# 67      2015-12-29    2545.0   2545.0
# 68      2015-09-30       NaN      NaN
# 69      2016-11-28    2546.0   2546.0
# 70      2019-02-04    2502.0   2502.0
# 71      2019-05-31    2711.0   2711.0
# 72      2022-11-29    2572.0   2572.0
# 73      2022-11-29    2567.0   2567.0
# 74      2022-11-29    2711.0   2711.0
# 75      2022-11-30    7253.0   7253.0
# 76      2022-11-30    3687.0   3687.0
# 77      2019-05-31    3390.0   3390.0
# 78      2017-12-30    2538.0   2538.0
# 79      2019-05-30    2823.0   2823.0
# 80      2019-05-31    2497.0   2497.0
# 81      2022-11-30    3684.0   3684.0
# 82      2019-05-31    2499.0   2499.0
# 83      2019-05-31    3684.0   3684.0
# 84      2019-05-31    2539.0   2539.0
# 85      2019-05-31    2498.0   2498.0
# 86      2014-10-31       NaN      NaN
# 87      2019-05-31    2563.0   2563.0
# 88      2019-05-31    3794.0   3794.0
# 89      2019-05-30    3795.0   3795.0
# 90      2022-11-30    3794.0   2498.0
# 91      2022-11-30    3795.0   3795.0
# 92      2019-05-31    2569.0   2569.0
# 93      2019-05-31    2568.0   2568.0
# 94      2014-10-31       NaN      NaN
# 95      2022-11-30    2569.0   2569.0
# 96      2022-11-30    2568.0   2568.0
# 97      2019-05-31    3293.0   3293.0
# 98      2022-11-30    3293.0   3293.0
# 99      2019-05-31    3292.0   3292.0
# 100     2022-11-29    3292.0   3292.0
# 101     2022-11-30    2823.0   2823.0
# 102     2022-11-27    4699.0   4699.0
# 103     2020-12-31    4699.0   4699.0
# 104     2019-04-18    2544.0   2544.0
# 105     2019-05-31    2822.0   2822.0
# 106     2022-11-30    3660.0   3660.0
# 107     2022-11-30    2544.0   2544.0
# 108     2022-11-29    2822.0   2822.0
# 109     2016-11-29    3381.0   3381.0
# 110     2022-11-30    2566.0   2566.0
# 111     2019-05-31    2547.0   2547.0
# 112     2017-04-30    3294.0   3294.0
# 113     2022-11-30    2548.0   2548.0
# 114     2019-05-31    3685.0   3685.0
# 115     2019-05-31    4058.0   4058.0
# 116     2022-11-30    4058.0   4058.0
# 117     2019-05-30    3791.0   3791.0
# 118     2019-05-31    3790.0   3790.0
# 119     2022-11-30    3790.0   3790.0
# 120     2022-11-30    3791.0   3791.0
# 121     2019-05-31    4062.0   4062.0
# 122     2019-05-31    4061.0   4061.0
# 123     2022-11-30    4061.0   4061.0
# 124     2022-11-30    4062.0   4062.0
# 125     2019-05-31    1007.0   3294.0
# 126     2019-05-31    2549.0   2549.0
# 127     2019-05-31    3660.0   3660.0
# 128     2019-05-31    3377.0   3377.0
# 129     2019-05-31    4059.0   4059.0
# 130     2022-11-30    4059.0   4059.0
# 131     2019-05-31    3838.0   3838.0
# 132     2019-05-31    3621.0   3621.0
# 133     2016-01-29    1008.0   1008.0
# 134     2022-11-30    7186.0   7186.0
# 135     2019-05-31    2567.0   2567.0
# 136     2017-04-25    3464.0   3464.0
# 137     2019-05-31    2566.0   2566.0
# 138     2022-11-30    2542.0   2542.0
# 139     2016-02-22    2576.0   2576.0
# 140     2019-05-31    2707.0   2707.0
# 141     2022-11-30    2707.0   2707.0
# 142     2022-01-25    2563.0   2563.0
# 143     2022-11-30    2563.0   2563.0
# 144     2019-05-31    2571.0   2571.0
# 145     2015-02-26       NaN      NaN
# 146     2022-11-30    4060.0   4060.0
# 147     2016-05-31    2500.0   2500.0
# 148     2019-05-31    3456.0   3455.0
# 149     2017-08-31    3455.0   3455.0
# 150     2016-07-12    2550.0   2550.0
# 151     2019-05-31    3793.0   3793.0
# 152     2022-11-30    7190.0   7190.0
# 153     2019-05-31    2575.0   2575.0
# 154     2022-11-29    2575.0   2575.0
# 155     2019-05-29    4052.0   4052.0
# 156     2019-05-27    4054.0   4054.0
# 157     2022-11-30    4052.0   4052.0
# 158     2022-11-29    4054.0   4054.0
# 159     2019-05-31    2562.0   2562.0
# 160     2022-11-30    2549.0   2549.0
# 161     2019-05-31    2570.0   2570.0
# 162     2019-05-31    3513.0   3513.0
# 163     2019-05-31    2504.0   2504.0
# 164     2019-05-31    2503.0   2503.0
# 165     2022-11-30    4048.0   4048.0
# 166     2022-11-30    2570.0   2570.0
# 167     2022-11-30    3513.0   3513.0
# 168     2022-11-30    2504.0   2504.0
# 169     2022-11-30    2503.0   2503.0
# 170     2022-11-30    7187.0   7187.0
# 171     2017-12-30    2541.0   2541.0
# 172     2019-05-31    2561.0   2561.0
# 173     2014-06-16    1005.0   1005.0
# 174     2019-05-31    3686.0   3686.0
# 175     2022-11-30    3686.0   3686.0
# 176     2015-12-17    2712.0   2712.0
# 177     2019-05-31    2565.0   2565.0
# 178     2019-05-31    2548.0   2548.0
# 179     2022-11-29    3377.0   3377.0
# 180     2016-05-30    2536.0   2536.0
# 181     2019-05-31    2537.0   2537.0
# 182     2022-11-29    2574.0   2574.0
# 183     2016-10-12    1006.0   1006.0
# 184     2015-08-31       NaN      NaN
# 185     2019-12-14    3684.0   3684.0

# %%
# Names wit missing ID numbers 
print('Names without ID numbers:')
name_dates_ids.loc[(name_dates_ids['First ID'].isnull()) |
                  (name_dates_ids['Last ID'].isnull()),'Kiosk Name'].unique()
# Out:
# Names without ID numbers:
# array(['ACC - West & 12th', 'Convention Center/ 3rd & Trinity',
#        'East 11th Street at Victory Grill', 'Red River @ LBJ Library',
#        'Zilker Park at Barton Springs & William Barton Drive'],
#       dtype=object)

# %%
name_dates_ids.columns
# Out:
# Index(['Kiosk Name', 'First Date Used', 'Last Date Used', 'First ID',
#        'Last ID'],
#       dtype='object')

# %% [markdown]
# Ok, want the LAST ID used for each Kiosk NAME

# %%
# Create a SMALLER DATAFRAME with the Last ID used for each Kiosk name
# df1 are the rows where First ID == Last ID, keeping the Last ID
# df2 are the rows where the kiosks with different First ID and Last ID,
# keeping the Last ID for further analysis

df1 = name_dates_ids.loc[(name_dates_ids["First ID"]==name_dates_ids["Last ID"]),{'Kiosk Name','Last ID','Last Date Used'}]

df2 = name_dates_ids.loc[(name_dates_ids["First ID"]!=name_dates_ids["Last ID"]) & 
                  (name_dates_ids["First ID"].notnull()) &
                  (name_dates_ids["Last ID"].notnull()),{'Kiosk Name','Last ID','Last Date Used'}]

# adding these MANUALLY, looked at other names
data = {'Last Date Used': ['2015-09-30',
                        '2014-10-31',
                        '2014-10-31',
                        '2015-02-26',
                        '2015-08-31'],
        'Kiosk Name': ['ACC - West & 12th', 
                      'Convention Center/ 3rd & Trinity',
                      'East 11th Street at Victory Grill',
                      'Red River @ LBJ Library',
                      'Zilker Park at Barton Springs & William Barton Drive'],
        'Last ID': [2546, 2539, 2568, 1004, 2574]}
df3 = pd.DataFrame(data)
df3['Last Date Used'] = pd.to_datetime(df3['Last Date Used'])

result = pd.DataFrame
frames = [df1, df2, df3]
result_temp = pd.concat(frames)

result0 = result_temp.sort_values(by = ["Last ID","Last Date Used"]).reset_index(drop=True)

result0
# Out:
#      Last ID       Last Date Used  \
# 0     1002.0           2014-06-30
# 1     1003.0           2014-06-12
# 2     1004.0  2015-02-26 00:00:00
# 3     1005.0           2014-06-16
# 4     1006.0           2016-10-12
# 5     1008.0           2016-01-29
# 6     2494.0           2019-05-31
# 7     2494.0           2022-11-30
# 8     2495.0           2019-05-31
# 9     2495.0           2022-11-30
# 10    2496.0           2019-05-31
# 11    2496.0           2022-11-29
# 12    2497.0           2019-05-31
# 13    2497.0           2022-11-30
# 14    2498.0           2019-05-31
# 15    2498.0           2019-06-20
# 16    2498.0           2022-11-30
# 17    2499.0           2019-05-31
# 18    2499.0           2022-11-30
# 19    2500.0           2016-05-31
# 20    2501.0           2019-05-29
# 21    2501.0           2022-11-30
# 22    2502.0           2019-02-04
# 23    2503.0           2019-05-31
# 24    2503.0           2022-11-30
# 25    2504.0           2019-05-31
# 26    2504.0           2022-11-30
# 27    2536.0           2016-05-30
# 28    2537.0           2019-05-31
# 29    2537.0           2022-11-29
# 30    2538.0           2017-12-30
# 31    2539.0  2014-10-31 00:00:00
# 32    2539.0           2019-05-31
# 33    2539.0           2022-11-30
# 34    2540.0           2019-05-31
# 35    2540.0           2020-04-11
# 36    2541.0           2017-12-30
# 37    2542.0           2022-11-30
# 38    2544.0           2019-04-18
# 39    2544.0           2022-11-30
# 40    2545.0           2015-12-29
# 41    2546.0  2015-09-30 00:00:00
# 42    2546.0           2016-11-28
# 43    2547.0           2019-05-31
# 44    2547.0           2022-11-30
# 45    2548.0           2019-05-31
# 46    2548.0           2022-11-30
# 47    2549.0           2019-05-31
# 48    2549.0           2022-11-30
# 49    2550.0           2016-07-12
# 50    2552.0           2019-05-31
# 51    2552.0           2022-11-30
# 52    2561.0           2019-05-31
# 53    2561.0           2022-11-30
# 54    2562.0           2019-05-31
# 55    2562.0           2022-11-30
# 56    2563.0           2019-05-31
# 57    2563.0           2022-01-25
# 58    2563.0           2022-11-30
# 59    2564.0           2017-03-03
# 60    2565.0           2019-05-31
# 61    2565.0           2022-11-30
# 62    2566.0           2019-05-31
# 63    2566.0           2022-11-30
# 64    2567.0           2019-05-31
# 65    2567.0           2022-11-29
# 66    2568.0  2014-10-31 00:00:00
# 67    2568.0           2019-05-31
# 68    2568.0           2022-11-30
# 69    2569.0           2019-05-31
# 70    2569.0           2022-11-30
# 71    2570.0           2019-05-31
# 72    2570.0           2022-11-30
# 73    2571.0           2019-05-31
# 74    2571.0           2022-11-30
# 75    2572.0           2022-11-29
# 76    2574.0  2015-08-31 00:00:00
# 77    2574.0           2022-11-29
# 78    2575.0           2019-05-31
# 79    2575.0           2022-11-29
# 80    2576.0           2016-02-22
# 81    2707.0           2019-05-31
# 82    2707.0           2022-11-30
# 83    2711.0           2019-05-31
# 84    2711.0           2022-11-29
# 85    2712.0           2015-12-17
# 86    2822.0           2019-05-31
# 87    2822.0           2022-11-29
# 88    2823.0           2019-05-30
# 89    2823.0           2022-11-30
# 90    3291.0           2019-05-31
# 91    3291.0           2022-10-02
# 92    3292.0           2019-05-31
# 93    3292.0           2022-11-29
# 94    3293.0           2019-05-31
# 95    3293.0           2022-11-30
# 96    3294.0           2017-04-30
# 97    3294.0           2019-05-31
# 98    3294.0           2022-11-30
# 99    3377.0           2019-05-31
# 100   3377.0           2022-11-29
# 101   3381.0           2016-11-29
# 102   3390.0           2019-05-31
# 103   3390.0           2022-11-30
# 104   3455.0           2017-08-31
# 105   3455.0           2019-05-31
# 106   3455.0           2019-10-31
# 107   3455.0           2022-11-30
# 108   3464.0           2017-04-25
# 109   3513.0           2019-05-31
# 110   3513.0           2022-11-30
# 111   3619.0           2019-05-31
# 112   3619.0           2022-11-30
# 113   3621.0           2019-05-31
# 114   3621.0           2022-11-30
# 115   3635.0           2019-05-31
# 116   3635.0           2020-11-18
# 117   3660.0           2019-05-31
# 118   3660.0           2022-11-30
# 119   3684.0           2019-05-31
# 120   3684.0           2019-12-14
# 121   3684.0           2022-11-30
# 122   3685.0           2019-05-31
# 123   3685.0           2022-11-30
# 124   3686.0           2019-05-31
# 125   3686.0           2022-11-30
# 126   3687.0           2022-11-30
# 127   3790.0           2019-05-31
# 128   3790.0           2022-11-30
# 129   3791.0           2019-05-30
# 130   3791.0           2022-11-30
# 131   3792.0           2019-05-31
# 132   3793.0           2019-05-31
# 133   3793.0           2022-02-22
# 134   3794.0           2019-05-31
# 135   3794.0           2022-11-29
# 136   3795.0           2019-05-30
# 137   3795.0           2022-11-30
# 138   3797.0           2019-05-31
# 139   3797.0           2022-11-30
# 140   3798.0           2019-05-31
# 141   3798.0           2022-11-30
# 142   3799.0           2019-05-31
# 143   3799.0           2022-11-30
# 144   3838.0           2019-05-31
# 145   3838.0           2022-11-30
# 146   3841.0           2019-05-31
# 147   3841.0           2021-09-28
# 148   4047.0           2019-05-31
# 149   4047.0           2022-11-30
# 150   4048.0           2022-11-30
# 151   4050.0           2019-05-31
# 152   4050.0           2022-11-30
# 153   4051.0           2019-05-31
# 154   4051.0           2022-11-30
# 155   4052.0           2019-05-29
# 156   4052.0           2022-11-30
# 157   4054.0           2019-05-27
# 158   4054.0           2022-11-29
# 159   4055.0           2019-05-31
# 160   4055.0           2022-11-30
# 161   4057.0           2019-05-31
# 162   4057.0           2022-11-30
# 163   4058.0           2019-05-31
# 164   4058.0           2022-11-30
# 165   4059.0           2019-05-31
# 166   4059.0           2022-11-30
# 167   4060.0           2022-11-30
# 168   4061.0           2019-05-31
# 169   4061.0           2022-11-30
# 170   4062.0           2019-05-31
# 171   4062.0           2022-11-30
# 172   4699.0           2020-12-31
# 173   4699.0           2022-11-27
# 174   4879.0           2022-11-30
# 175   4938.0           2022-11-30
# 176   7125.0           2022-05-31
# 177   7125.0           2022-11-30
# 178   7131.0           2022-03-31
# 179   7131.0           2022-11-30
# 180   7186.0           2022-11-30
# 181   7187.0           2022-11-30
# 182   7188.0           2022-11-30
# 183   7189.0           2022-11-30
# 184   7190.0           2022-11-30
# 185   7253.0           2022-11-30
#
#                                             Kiosk Name
# 0                                   6th & Navasota St.
# 1                                      8th & Guadalupe
# 2                              Red River @ LBJ Library
# 3                 State Parking Garage @ Brazos & 18th
# 4                                     Zilker Park West
# 5                                         Nueces @ 3rd
# 6                                       2nd & Congress
# 7                                         2nd/Congress
# 8                                       4th & Congress
# 9                                         4th/Congress
# 10                                      8th & Congress
# 11                                        8th/Congress
# 12                   Capitol Station / Congress & 11th
# 13                   11th/Congress @ The Texas Capitol
# 14             Convention Center / 4th St. @ MetroRail
# 15                     4th/Neches @ MetroRail Downtown
# 16                                Dean Keeton/Speedway
# 17                            City Hall / Lavaca & 2nd
# 18                              2nd/Lavaca @ City Hall
# 19                                     Republic Square
# 20                                         5th & Bowie
# 21                                           5th/Bowie
# 22                          Barton Springs & Riverside
# 23                              South Congress & James
# 24                                South Congress/James
# 25                          South Congress & Elizabeth
# 26                            South Congress/Elizabeth
# 27                                    Waller & 6th St.
# 28                                      West & 6th St.
# 29                                            6th/West
# 30                     Bullock Museum @ Congress & MLK
# 31                    Convention Center/ 3rd & Trinity
# 32                   Convention Center / 3rd & Trinity
# 33                 3rd/Trinity @ The Convention Center
# 34                                    17th & Guadalupe
# 35                                      17th/Guadalupe
# 36                     State Capitol @ 14th & Colorado
# 37                                      Plaza Saltillo
# 38                           East 6th & Pedernales St.
# 39                                 East 6th/Pedernales
# 40                             ACC - Rio Grande & 12th
# 41                                   ACC - West & 12th
# 42                            ACC - West & 12th Street
# 43                                    Guadalupe & 21st
# 44                                      21st/Guadalupe
# 45                            UT West Mall @ Guadalupe
# 46              Guadalupe/West Mall @ University Co-op
# 47                 Long Center @ South 1st & Riverside
# 48                   South 1st/Riverside @ Long Center
# 49               Republic Square @ Guadalupe & 4th St.
# 50                                          3rd & West
# 51                                            3rd/West
# 52   State Capitol Visitors Garage @ San Jacinto & ...
# 53    12th/San Jacinto @ State Capitol Visitors Garage
# 54                            San Jacinto & 8th Street
# 55                                     8th/San Jacinto
# 56                              Davis at Rainey Street
# 57                                        Rainey/Davis
# 58                                     Rainey/Driskill
# 59                                    5th & San Marcos
# 60                                Trinity & 6th Street
# 61                                         6th/Trinity
# 62                       Pfluger Bridge @ W 2nd Street
# 63   Electric Drive/Sandra Muraida Way @ Pfluger Pe...
# 64                                   Palmer Auditorium
# 65          Barton Springs/Bouldin @ Palmer Auditorium
# 66                   East 11th Street at Victory Grill
# 67                      East 11th St. at Victory Grill
# 68                             East 11th/Victory Grill
# 69                          East 11th St. & San Marcos
# 70                                East 11th/San Marcos
# 71                            South Congress & Academy
# 72                              South Congress/Academy
# 73                              Red River & 8th Street
# 74                                       8th/Red River
# 75                                 Barton Springs Pool
# 76   Zilker Park at Barton Springs & William Barton...
# 77                                         Zilker Park
# 78                                Riverside @ S. Lamar
# 79                               Riverside/South Lamar
# 80                                   Rainey @ River St
# 81                                Rainey St @ Cummings
# 82                                     Rainey/Cummings
# 83                         Barton Springs @ Kinney Ave
# 84                               Barton Springs/Kinney
# 85                             Toomey Rd @ South Lamar
# 86                         East 6th at Robert Martinez
# 87                         East 6th/Robert T. Martinez
# 88             Capital Metro HQ - East 5th at Broadway
# 89                East 5th/Broadway @ Capital Metro HQ
# 90                                  11th & San Jacinto
# 91                                    11th/San Jacinto
# 92                                   East 4th & Chicon
# 93                                     East 4th/Chicon
# 94                               East 2nd & Pedernales
# 95                                 East 2nd/Pedernales
# 96                                     Guadalupe & 6th
# 97                                        Lavaca & 6th
# 98                                          6th/Lavaca
# 99            MoPac Pedestrian Bridge @ Veterans Drive
# 100                Veterans/Atlanta @ MoPac Ped Bridge
# 101                         East 7th & Pleasant Valley
# 102                                       Brazos & 6th
# 103                                         6th/Brazos
# 104         Republic Square @ Federal Courthouse Plaza
# 105                  Republic Square @ 5th & Guadalupe
# 106                    5th/Guadalupe @ Republic Square
# 107                    4th/Guadalupe @ Republic Square
# 108                                         Pease Park
# 109  South Congress & Barton Springs at the Austin ...
# 110  South Congress/Barton Springs @ The Austin Ame...
# 111                                     6th & Congress
# 112                                       6th/Congress
# 113                                       Nueces & 3rd
# 114                                         3rd/Nueces
# 115                                 13th & San Antonio
# 116                                   13th/San Antonio
# 117                                  Medina & East 6th
# 118                                    East 6th/Medina
# 119                            Congress & Cesar Chavez
# 120                              cesar Chavez/Congress
# 121                              Cesar Chavez/Congress
# 122                                    Henderson & 9th
# 123                                      9th/Henderson
# 124                         Sterzing at Barton Springs
# 125                            Sterzing/Barton Springs
# 126                                     Boardwalk West
# 127                       Lake Austin Blvd @ Deep Eddy
# 128                         Lake Austin Blvd/Deep Eddy
# 129                              Lake Austin & Enfield
# 130                                Lake Austin/Enfield
# 131                                       22nd & Pearl
# 132                                  Rio Grande & 28th
# 133                                    28th/Rio Grande
# 134                             Dean Keeton & Speedway
# 135                                         4th/Sabine
# 136                               Dean Keeton & Whitis
# 137                                 Dean Keeton/Whitis
# 138                                  21st & University
# 139                                    21st/University
# 140                               21st & Speedway @PCL
# 141                                21st/Speedway @ PCL
# 142                   23rd & San Jacinto @ DKR Stadium
# 143                     23rd/San Jacinto @ DKR Stadium
# 144                                      Nueces & 26th
# 145                                        26th/Nueces
# 146                                  23rd & Rio Grande
# 147                                    23rd/Rio Grande
# 148                                       8th & Lavaca
# 149                                         8th/Lavaca
# 150                     South Congress @ Bouldin Creek
# 151                                     5th & Campbell
# 152                                       5th/Campbell
# 153                                   10th & Red River
# 154                                     10th/Red River
# 155                                Rosewood & Angelina
# 156                                  Rosewood/Angelina
# 157                                  Rosewood & Chicon
# 158                                    Rosewood/Chicon
# 159                                      11th & Salina
# 160                                        11th/Salina
# 161                                     6th & Chalmers
# 162                                       6th/Chalmers
# 163                        Hollow Creek & Barton Hills
# 164                          Hollow Creek/Barton Hills
# 165                         Nash Hernandez @ RBJ South
# 166                    Nash Hernandez/East @ RBJ South
# 167              Red River/Cesar Chavez @ The Fairmont
# 168                          Lakeshore @ Austin Hostel
# 169                            Lakeshore/Austin Hostel
# 170                        Lakeshore & Pleasant Valley
# 171                          Lakeshore/Pleasant Valley
# 172                                  East 5th/Shady Ln
# 173                East 5th/Shady @ Eastside Bus Plaza
# 174                                   16th/San Antonio
# 175                                    22.5/Rio Grande
# 176                                   23rd/San Gabriel
# 177                                         23rd/Pearl
# 178                                       13th/Trinity
# 179                   13th/Trinity @ Waterloo Greenway
# 180                                   One Texas Center
# 181                                South Congress/Mary
# 182                                         22nd/Pearl
# 183                                           28th/Rio
# 184                                    Rio Grande/12th
# 185                           Barton Springs/Riverside

# %% [markdown]
# ## 4. Okay, manually examine kiosk ID numbers with multiple names

# %%
result0["Last ID"].unique()
# Out:
# array([1002., 1003., 1004., 1005., 1006., 1008., 2494., 2495., 2496.,
#        2497., 2498., 2499., 2500., 2501., 2502., 2503., 2504., 2536.,
#        2537., 2538., 2539., 2540., 2541., 2542., 2544., 2545., 2546.,
#        2547., 2548., 2549., 2550., 2552., 2561., 2562., 2563., 2564.,
#        2565., 2566., 2567., 2568., 2569., 2570., 2571., 2572., 2574.,
#        2575., 2576., 2707., 2711., 2712., 2822., 2823., 3291., 3292.,
#        3293., 3294., 3377., 3381., 3390., 3455., 3464., 3513., 3619.,
#        3621., 3635., 3660., 3684., 3685., 3686., 3687., 3790., 3791.,
#        3792., 3793., 3794., 3795., 3797., 3798., 3799., 3838., 3841.,
#        4047., 4048., 4050., 4051., 4052., 4054., 4055., 4057., 4058.,
#        4059., 4060., 4061., 4062., 4699., 4879., 4938., 7125., 7131.,
#        7186., 7187., 7188., 7189., 7190., 7253.])

# %%
single_name_ids = []
multip_name_ids = []

for k_id in result0["Last ID"].unique():
    
    if len(result0.loc[result0["Last ID"]==k_id,"Kiosk Name"].to_list())>=2:
        multip_name_ids.append(k_id)
        print(k_id)
        print(result0.loc[result0["Last ID"]==k_id,"Kiosk Name"].to_list())
        print("\n")
    else:
        single_name_ids.append(k_id)
# Out:
# 2494.0
# ['2nd & Congress', '2nd/Congress']
#
#
# 2495.0
# ['4th & Congress', '4th/Congress']
#
#
# 2496.0
# ['8th & Congress', '8th/Congress']
#
#
# 2497.0
# ['Capitol Station / Congress & 11th', '11th/Congress @ The Texas Capitol']
#
#
# 2498.0
# ['Convention Center / 4th St. @ MetroRail', '4th/Neches @ MetroRail Downtown', 'Dean Keeton/Speedway']
#
#
# 2499.0
# ['City Hall / Lavaca & 2nd', '2nd/Lavaca @ City Hall']
#
#
# 2501.0
# ['5th & Bowie', '5th/Bowie']
#
#
# 2503.0
# ['South Congress & James', 'South Congress/James']
#
#
# 2504.0
# ['South Congress & Elizabeth', 'South Congress/Elizabeth']
#
#
# 2537.0
# ['West & 6th St.', '6th/West']
#
#
# 2539.0
# ['Convention Center/ 3rd & Trinity', 'Convention Center / 3rd & Trinity', '3rd/Trinity @ The Convention Center']
#
#
# 2540.0
# ['17th & Guadalupe', '17th/Guadalupe']
#
#
# 2544.0
# ['East 6th & Pedernales St.', 'East 6th/Pedernales']
#
#
# 2546.0
# ['ACC - West & 12th', 'ACC - West & 12th Street']
#
#
# 2547.0
# ['Guadalupe & 21st', '21st/Guadalupe']
#
#
# 2548.0
# ['UT West Mall @ Guadalupe', 'Guadalupe/West Mall @ University Co-op']
#
#
# 2549.0
# ['Long Center @ South 1st & Riverside', 'South 1st/Riverside @ Long Center']
#
#
# 2552.0
# ['3rd & West', '3rd/West']
#
#
# 2561.0
# ['State Capitol Visitors Garage @ San Jacinto & 12th', '12th/San Jacinto @ State Capitol Visitors Garage']
#
#
# 2562.0
# ['San Jacinto & 8th Street', '8th/San Jacinto']
#
#
# 2563.0
# ['Davis at Rainey Street', 'Rainey/Davis', 'Rainey/Driskill']
#
#
# 2565.0
# ['Trinity & 6th Street', '6th/Trinity']
#
#
# 2566.0
# ['Pfluger Bridge @ W 2nd Street', 'Electric Drive/Sandra Muraida Way @ Pfluger Ped Bridge']
#
#
# 2567.0
# ['Palmer Auditorium', 'Barton Springs/Bouldin @ Palmer Auditorium']
#
#
# 2568.0
# ['East 11th Street at Victory Grill', 'East 11th St. at Victory Grill', 'East 11th/Victory Grill']
#
#
# 2569.0
# ['East 11th St. & San Marcos', 'East 11th/San Marcos']
#
#
# 2570.0
# ['South Congress & Academy', 'South Congress/Academy']
#
#
# 2571.0
# ['Red River & 8th Street', '8th/Red River']
#
#
# 2574.0
# ['Zilker Park at Barton Springs & William Barton Drive', 'Zilker Park']
#
#
# 2575.0
# ['Riverside @ S. Lamar', 'Riverside/South Lamar']
#
#
# 2707.0
# ['Rainey St @ Cummings', 'Rainey/Cummings']
#
#
# 2711.0
# ['Barton Springs @ Kinney Ave', 'Barton Springs/Kinney']
#
#
# 2822.0
# ['East 6th at Robert Martinez', 'East 6th/Robert T. Martinez']
#
#
# 2823.0
# ['Capital Metro HQ - East 5th at Broadway', 'East 5th/Broadway @ Capital Metro HQ']
#
#
# 3291.0
# ['11th & San Jacinto', '11th/San Jacinto']
#
#
# 3292.0
# ['East 4th & Chicon', 'East 4th/Chicon']
#
#
# 3293.0
# ['East 2nd & Pedernales', 'East 2nd/Pedernales']
#
#
# 3294.0
# ['Guadalupe & 6th', 'Lavaca & 6th', '6th/Lavaca']
#
#
# 3377.0
# ['MoPac Pedestrian Bridge @ Veterans Drive', 'Veterans/Atlanta @ MoPac Ped Bridge']
#
#
# 3390.0
# ['Brazos & 6th', '6th/Brazos']
#
#
# 3455.0
# ['Republic Square @ Federal Courthouse Plaza', 'Republic Square @ 5th & Guadalupe', '5th/Guadalupe @ Republic Square', '4th/Guadalupe @ Republic Square']
#
#
# 3513.0
# ['South Congress & Barton Springs at the Austin American-Statesman', 'South Congress/Barton Springs @ The Austin American-Statesman']
#
#
# 3619.0
# ['6th & Congress', '6th/Congress']
#
#
# 3621.0
# ['Nueces & 3rd', '3rd/Nueces']
#
#
# 3635.0
# ['13th & San Antonio', '13th/San Antonio']
#
#
# 3660.0
# ['Medina & East 6th', 'East 6th/Medina']
#
#
# 3684.0
# ['Congress & Cesar Chavez', 'cesar Chavez/Congress', 'Cesar Chavez/Congress']
#
#
# 3685.0
# ['Henderson & 9th', '9th/Henderson']
#
#
# 3686.0
# ['Sterzing at Barton Springs', 'Sterzing/Barton Springs']
#
#
# 3790.0
# ['Lake Austin Blvd @ Deep Eddy', 'Lake Austin Blvd/Deep Eddy']
#
#
# 3791.0
# ['Lake Austin & Enfield', 'Lake Austin/Enfield']
#
#
# 3793.0
# ['Rio Grande & 28th', '28th/Rio Grande']
#
#
# 3794.0
# ['Dean Keeton & Speedway', '4th/Sabine']
#
#
# 3795.0
# ['Dean Keeton & Whitis', 'Dean Keeton/Whitis']
#
#
# 3797.0
# ['21st & University', '21st/University']
#
#
# 3798.0
# ['21st & Speedway @PCL', '21st/Speedway @ PCL']
#
#
# 3799.0
# ['23rd & San Jacinto @ DKR Stadium', '23rd/San Jacinto @ DKR Stadium']
#
#
# 3838.0
# ['Nueces & 26th', '26th/Nueces']
#
#
# 3841.0
# ['23rd & Rio Grande', '23rd/Rio Grande']
#
#
# 4047.0
# ['8th & Lavaca', '8th/Lavaca']
#
#
# 4050.0
# ['5th & Campbell', '5th/Campbell']
#
#
# 4051.0
# ['10th & Red River', '10th/Red River']
#
#
# 4052.0
# ['Rosewood & Angelina', 'Rosewood/Angelina']
#
#
# 4054.0
# ['Rosewood & Chicon', 'Rosewood/Chicon']
#
#
# 4055.0
# ['11th & Salina', '11th/Salina']
#
#
# 4057.0
# ['6th & Chalmers', '6th/Chalmers']
#
#
# 4058.0
# ['Hollow Creek & Barton Hills', 'Hollow Creek/Barton Hills']
#
#
# 4059.0
# ['Nash Hernandez @ RBJ South', 'Nash Hernandez/East @ RBJ South']
#
#
# 4061.0
# ['Lakeshore @ Austin Hostel', 'Lakeshore/Austin Hostel']
#
#
# 4062.0
# ['Lakeshore & Pleasant Valley', 'Lakeshore/Pleasant Valley']
#
#
# 4699.0
# ['East 5th/Shady Ln', 'East 5th/Shady @ Eastside Bus Plaza']
#
#
# 7125.0
# ['23rd/San Gabriel', '23rd/Pearl']
#
#
# 7131.0
# ['13th/Trinity', '13th/Trinity @ Waterloo Greenway']

# %%
# Manually examined the data above.

# %% [markdown]
# ## Looking more closely at 2498, 3455, 3794

# %% [markdown]
# ### Kiosk ID 2498

# %%
result0.loc[result0["Last ID"]==2498]
# ok I think "Dean Keeton/Speedway" is currently ID 2498 based on the date of 2022-11-30
# Out:
#     Last ID Last Date Used                               Kiosk Name
# 14   2498.0     2019-05-31  Convention Center / 4th St. @ MetroRail
# 15   2498.0     2019-06-20          4th/Neches @ MetroRail Downtown
# 16   2498.0     2022-11-30                     Dean Keeton/Speedway

# %%
result0.loc[result0["Kiosk Name"].str.contains("Speedway")]
# also "Dean Keeton & Speedway"
# Out:
#      Last ID Last Date Used              Kiosk Name
# 16    2498.0     2022-11-30    Dean Keeton/Speedway
# 134   3794.0     2019-05-31  Dean Keeton & Speedway
# 140   3798.0     2019-05-31    21st & Speedway @PCL
# 141   3798.0     2022-11-30     21st/Speedway @ PCL

# %%
# Is there another ID for "MetroRail"?
result0.loc[result0["Kiosk Name"].str.contains("MetroRail")]

# Answer is NO...
# Out:
#     Last ID Last Date Used                               Kiosk Name
# 14   2498.0     2019-05-31  Convention Center / 4th St. @ MetroRail
# 15   2498.0     2019-06-20          4th/Neches @ MetroRail Downtown

# %%
# What about the Convention Center..?
result0.loc[result0["Kiosk Name"].str.contains("Convention")]
# Out:
#     Last ID       Last Date Used                               Kiosk Name
# 14   2498.0           2019-05-31  Convention Center / 4th St. @ MetroRail
# 31   2539.0  2014-10-31 00:00:00         Convention Center/ 3rd & Trinity
# 32   2539.0           2019-05-31        Convention Center / 3rd & Trinity
# 33   2539.0           2022-11-30      3rd/Trinity @ The Convention Center

# %%
# ok I think ID 2539 is for the Convention Center location - which includes the following:

# - Convention Center / 4th St. @ MetroRail
# - 4th/Neches @ MetroRail Downtown
# - Convention Center / 3rd & Trinity
# - 3rd/Trinity @ The Convention Center

# This station moved around the corner, but I will name all these set to ID 2539.

# %% [markdown]
# ### Kiosk ID 3455

# %%
result0.loc[result0["Last ID"]==3455]
# Out:
#      Last ID Last Date Used                                  Kiosk Name
# 104   3455.0     2017-08-31  Republic Square @ Federal Courthouse Plaza
# 105   3455.0     2019-05-31           Republic Square @ 5th & Guadalupe
# 106   3455.0     2019-10-31             5th/Guadalupe @ Republic Square
# 107   3455.0     2022-11-30             4th/Guadalupe @ Republic Square

# %%
result0.loc[result0["Kiosk Name"].str.contains('Republic Square')]
# Out:
#      Last ID Last Date Used                                  Kiosk Name
# 19    2500.0     2016-05-31                             Republic Square
# 49    2550.0     2016-07-12       Republic Square @ Guadalupe & 4th St.
# 104   3455.0     2017-08-31  Republic Square @ Federal Courthouse Plaza
# 105   3455.0     2019-05-31           Republic Square @ 5th & Guadalupe
# 106   3455.0     2019-10-31             5th/Guadalupe @ Republic Square
# 107   3455.0     2022-11-30             4th/Guadalupe @ Republic Square

# %%
result0.loc[result0["Kiosk Name"].str.contains('Republic Square'),'Kiosk Name']
# Out:
# 19                                Republic Square
# 49          Republic Square @ Guadalupe & 4th St.
# 104    Republic Square @ Federal Courthouse Plaza
# 105             Republic Square @ 5th & Guadalupe
# 106               5th/Guadalupe @ Republic Square
# 107               4th/Guadalupe @ Republic Square
# Name: Kiosk Name, dtype: object

# %%
# Ok, naming all these Republic Square kiosks with ID 3455 (based on the 2022 date)
# - Republic Square
# - Republic Square @ Guadalupe & 4th St.
# - Republic Square @ Federal Courthouse Plaza
# - Republic Square @ 5th & Guadalupe
# - 5th/Guadalupe @ Republic Square
# - 4th/Guadalupe @ Republic Square

# %% [markdown]
# ### Kiosk ID 3794

# %%
result0.loc[result0["Last ID"]==3794]
# Out:
#      Last ID Last Date Used              Kiosk Name
# 134   3794.0     2019-05-31  Dean Keeton & Speedway
# 135   3794.0     2022-11-29              4th/Sabine

# %%
# ok I think ID 3794 includes the following:

# - 4th/Sabine

# %%
# make adjustments here
multip_name_ids.remove(2498)
multip_name_ids.remove(3455)
multip_name_ids.remove(3794)

# %% [markdown]
# ## Looking for similar names with different IDs?

# %%
# https://stackoverflow.com/questions/17388213/find-the-similarity-metric-between-two-strings
# Function to help find kiosk IDs with multiple names 
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# e.g.
similar("23rd/San Gabriel","23rd & San Gabriel")
# Out:
# 0.8823529411764706

# %%
# Manually adding these
# Dean Keeton/Speedway	2498	2022-11-30
# Dean Keeton & Speedway	2498	2000-01-01
# Convention Center / 4th St. @ MetroRail	2539	2000-01-01
# 4th/Neches @ MetroRail Downtown	2539	2000-01-01
# Convention Center / 3rd & Trinity	2539	2019-05-31
# 3rd/Trinity @ The Convention Center	2539	2022-11-30
# Republic Square	3455	2016-05-31
# Republic Square @ Guadalupe & 4th St.	3455	2016-07-12
# Republic Square @ Federal Courthouse Plaza	3455	2017-08-31
# Republic Square @ 5th & Guadalupe	3455	2019-05-31
# 5th/Guadalupe @ Republic Square	3455	2019-10-31
# 4th/Guadalupe @ Republic Square	3455	2022-11-30
# 4th/Sabine	3794	2022-11-29

# %%
result0.columns
# Out:
# Index(['Last ID', 'Last Date Used', 'Kiosk Name'], dtype='object')

# %%
df_a = result0.loc[result0["Last ID"].isin(single_name_ids)]
df_b = result0.loc[result0["Last ID"].isin(multip_name_ids)]

# %%
df_c = pd.DataFrame({'Kiosk Name': ['Dean Keeton/Speedway',
                                    'Dean Keeton & Speedway',
                                    'Convention Center / 4th St. @ MetroRail',
                                    '4th/Neches @ MetroRail Downtown',
                                    'Convention Center / 3rd & Trinity',
                                    '3rd/Trinity @ The Convention Center',
                                    'Republic Square',
                                    'Republic Square @ Guadalupe & 4th St.',
                                    'Republic Square @ Federal Courthouse Plaza',
                                    'Republic Square @ 5th & Guadalupe',
                                    '5th/Guadalupe @ Republic Square',
                                    '4th/Guadalupe @ Republic Square',
                                    '4th/Sabine'],
                    'Last ID': [2498,2498,2539,2539,2539,2539,3455,3455,3455,3455,3455,3455,3794],
                    'Last Date Used': [datetime.strptime('2022-11-30','%Y-%m-%d'),
                                       datetime.strptime('2000-01-01','%Y-%m-%d'), # placeholder
                                       datetime.strptime('2000-01-01','%Y-%m-%d'), # placeholder
                                       datetime.strptime('2000-01-01','%Y-%m-%d'), # placeholder
                                       datetime.strptime('2019-05-31','%Y-%m-%d'),
                                       datetime.strptime('2022-11-30','%Y-%m-%d'),
                                       datetime.strptime('2016-05-31','%Y-%m-%d'),
                                       datetime.strptime('2016-07-12','%Y-%m-%d'),
                                       datetime.strptime('2017-08-31','%Y-%m-%d'),
                                       datetime.strptime('2019-05-31','%Y-%m-%d'),
                                       datetime.strptime('2019-10-31','%Y-%m-%d'),
                                       datetime.strptime('2022-11-30','%Y-%m-%d'),
                                       datetime.strptime('2022-11-29','%Y-%m-%d')]})

# %%
result = pd.DataFrame
frames2 = [df_a, df_b, df_c]
result = pd.concat(frames2).sort_values(by = ["Last ID"]).reset_index(drop=True)

# %%
result
# Out:
#      Last ID       Last Date Used  \
# 0     1002.0           2014-06-30
# 1     1003.0           2014-06-12
# 2     1004.0  2015-02-26 00:00:00
# 3     1005.0           2014-06-16
# 4     1006.0           2016-10-12
# 5     1008.0           2016-01-29
# 6     2494.0           2019-05-31
# 7     2494.0           2022-11-30
# 8     2495.0           2019-05-31
# 9     2495.0           2022-11-30
# 10    2496.0           2022-11-29
# 11    2496.0           2019-05-31
# 12    2497.0           2022-11-30
# 13    2497.0           2019-05-31
# 14    2498.0  2000-01-01 00:00:00
# 15    2498.0  2022-11-30 00:00:00
# 16    2499.0           2022-11-30
# 17    2499.0           2019-05-31
# 18    2500.0           2016-05-31
# 19    2501.0           2022-11-30
# 20    2501.0           2019-05-29
# 21    2502.0           2019-02-04
# 22    2503.0           2022-11-30
# 23    2503.0           2019-05-31
# 24    2504.0           2022-11-30
# 25    2504.0           2019-05-31
# 26    2536.0           2016-05-30
# 27    2537.0           2022-11-29
# 28    2537.0           2019-05-31
# 29    2538.0           2017-12-30
# 30    2539.0  2000-01-01 00:00:00
# 31    2539.0  2000-01-01 00:00:00
# 32    2539.0           2019-05-31
# 33    2539.0  2014-10-31 00:00:00
# 34    2539.0           2022-11-30
# 35    2539.0  2022-11-30 00:00:00
# 36    2539.0  2019-05-31 00:00:00
# 37    2540.0           2020-04-11
# 38    2540.0           2019-05-31
# 39    2541.0           2017-12-30
# 40    2542.0           2022-11-30
# 41    2544.0           2022-11-30
# 42    2544.0           2019-04-18
# 43    2545.0           2015-12-29
# 44    2546.0           2016-11-28
# 45    2546.0  2015-09-30 00:00:00
# 46    2547.0           2019-05-31
# 47    2547.0           2022-11-30
# 48    2548.0           2022-11-30
# 49    2548.0           2019-05-31
# 50    2549.0           2022-11-30
# 51    2549.0           2019-05-31
# 52    2550.0           2016-07-12
# 53    2552.0           2019-05-31
# 54    2552.0           2022-11-30
# 55    2561.0           2019-05-31
# 56    2561.0           2022-11-30
# 57    2562.0           2019-05-31
# 58    2562.0           2022-11-30
# 59    2563.0           2019-05-31
# 60    2563.0           2022-01-25
# 61    2563.0           2022-11-30
# 62    2564.0           2017-03-03
# 63    2565.0           2022-11-30
# 64    2565.0           2019-05-31
# 65    2566.0           2022-11-30
# 66    2566.0           2019-05-31
# 67    2567.0           2022-11-29
# 68    2567.0           2019-05-31
# 69    2568.0           2022-11-30
# 70    2568.0  2014-10-31 00:00:00
# 71    2568.0           2019-05-31
# 72    2569.0           2022-11-30
# 73    2569.0           2019-05-31
# 74    2570.0           2022-11-30
# 75    2570.0           2019-05-31
# 76    2571.0           2019-05-31
# 77    2571.0           2022-11-30
# 78    2572.0           2022-11-29
# 79    2574.0  2015-08-31 00:00:00
# 80    2574.0           2022-11-29
# 81    2575.0           2019-05-31
# 82    2575.0           2022-11-29
# 83    2576.0           2016-02-22
# 84    2707.0           2019-05-31
# 85    2707.0           2022-11-30
# 86    2711.0           2019-05-31
# 87    2711.0           2022-11-29
# 88    2712.0           2015-12-17
# 89    2822.0           2022-11-29
# 90    2822.0           2019-05-31
# 91    2823.0           2022-11-30
# 92    2823.0           2019-05-30
# 93    3291.0           2022-10-02
# 94    3291.0           2019-05-31
# 95    3292.0           2019-05-31
# 96    3292.0           2022-11-29
# 97    3293.0           2019-05-31
# 98    3293.0           2022-11-30
# 99    3294.0           2017-04-30
# 100   3294.0           2019-05-31
# 101   3294.0           2022-11-30
# 102   3377.0           2022-11-29
# 103   3377.0           2019-05-31
# 104   3381.0           2016-11-29
# 105   3390.0           2022-11-30
# 106   3390.0           2019-05-31
# 107   3455.0  2016-05-31 00:00:00
# 108   3455.0  2016-07-12 00:00:00
# 109   3455.0  2017-08-31 00:00:00
# 110   3455.0  2022-11-30 00:00:00
# 111   3455.0  2019-05-31 00:00:00
# 112   3455.0  2019-10-31 00:00:00
# 113   3464.0           2017-04-25
# 114   3513.0           2019-05-31
# 115   3513.0           2022-11-30
# 116   3619.0           2019-05-31
# 117   3619.0           2022-11-30
# 118   3621.0           2019-05-31
# 119   3621.0           2022-11-30
# 120   3635.0           2020-11-18
# 121   3635.0           2019-05-31
# 122   3660.0           2019-05-31
# 123   3660.0           2022-11-30
# 124   3684.0           2019-12-14
# 125   3684.0           2022-11-30
# 126   3684.0           2019-05-31
# 127   3685.0           2019-05-31
# 128   3685.0           2022-11-30
# 129   3686.0           2019-05-31
# 130   3686.0           2022-11-30
# 131   3687.0           2022-11-30
# 132   3790.0           2019-05-31
# 133   3790.0           2022-11-30
# 134   3791.0           2022-11-30
# 135   3791.0           2019-05-30
# 136   3792.0           2019-05-31
# 137   3793.0           2019-05-31
# 138   3793.0           2022-02-22
# 139   3794.0  2022-11-29 00:00:00
# 140   3795.0           2019-05-30
# 141   3795.0           2022-11-30
# 142   3797.0           2022-11-30
# 143   3797.0           2019-05-31
# 144   3798.0           2019-05-31
# 145   3798.0           2022-11-30
# 146   3799.0           2019-05-31
# 147   3799.0           2022-11-30
# 148   3838.0           2019-05-31
# 149   3838.0           2022-11-30
# 150   3841.0           2019-05-31
# 151   3841.0           2021-09-28
# 152   4047.0           2019-05-31
# 153   4047.0           2022-11-30
# 154   4048.0           2022-11-30
# 155   4050.0           2022-11-30
# 156   4050.0           2019-05-31
# 157   4051.0           2019-05-31
# 158   4051.0           2022-11-30
# 159   4052.0           2019-05-29
# 160   4052.0           2022-11-30
# 161   4054.0           2019-05-27
# 162   4054.0           2022-11-29
# 163   4055.0           2019-05-31
# 164   4055.0           2022-11-30
# 165   4057.0           2019-05-31
# 166   4057.0           2022-11-30
# 167   4058.0           2019-05-31
# 168   4058.0           2022-11-30
# 169   4059.0           2019-05-31
# 170   4059.0           2022-11-30
# 171   4060.0           2022-11-30
# 172   4061.0           2019-05-31
# 173   4061.0           2022-11-30
# 174   4062.0           2019-05-31
# 175   4062.0           2022-11-30
# 176   4699.0           2022-11-27
# 177   4699.0           2020-12-31
# 178   4879.0           2022-11-30
# 179   4938.0           2022-11-30
# 180   7125.0           2022-11-30
# 181   7125.0           2022-05-31
# 182   7131.0           2022-11-30
# 183   7131.0           2022-03-31
# 184   7186.0           2022-11-30
# 185   7187.0           2022-11-30
# 186   7188.0           2022-11-30
# 187   7189.0           2022-11-30
# 188   7190.0           2022-11-30
# 189   7253.0           2022-11-30
#
#                                             Kiosk Name
# 0                                   6th & Navasota St.
# 1                                      8th & Guadalupe
# 2                              Red River @ LBJ Library
# 3                 State Parking Garage @ Brazos & 18th
# 4                                     Zilker Park West
# 5                                         Nueces @ 3rd
# 6                                       2nd & Congress
# 7                                         2nd/Congress
# 8                                       4th & Congress
# 9                                         4th/Congress
# 10                                        8th/Congress
# 11                                      8th & Congress
# 12                   11th/Congress @ The Texas Capitol
# 13                   Capitol Station / Congress & 11th
# 14                              Dean Keeton & Speedway
# 15                                Dean Keeton/Speedway
# 16                              2nd/Lavaca @ City Hall
# 17                            City Hall / Lavaca & 2nd
# 18                                     Republic Square
# 19                                           5th/Bowie
# 20                                         5th & Bowie
# 21                          Barton Springs & Riverside
# 22                                South Congress/James
# 23                              South Congress & James
# 24                            South Congress/Elizabeth
# 25                          South Congress & Elizabeth
# 26                                    Waller & 6th St.
# 27                                            6th/West
# 28                                      West & 6th St.
# 29                     Bullock Museum @ Congress & MLK
# 30                     4th/Neches @ MetroRail Downtown
# 31             Convention Center / 4th St. @ MetroRail
# 32                   Convention Center / 3rd & Trinity
# 33                    Convention Center/ 3rd & Trinity
# 34                 3rd/Trinity @ The Convention Center
# 35                 3rd/Trinity @ The Convention Center
# 36                   Convention Center / 3rd & Trinity
# 37                                      17th/Guadalupe
# 38                                    17th & Guadalupe
# 39                     State Capitol @ 14th & Colorado
# 40                                      Plaza Saltillo
# 41                                 East 6th/Pedernales
# 42                           East 6th & Pedernales St.
# 43                             ACC - Rio Grande & 12th
# 44                            ACC - West & 12th Street
# 45                                   ACC - West & 12th
# 46                                    Guadalupe & 21st
# 47                                      21st/Guadalupe
# 48              Guadalupe/West Mall @ University Co-op
# 49                            UT West Mall @ Guadalupe
# 50                   South 1st/Riverside @ Long Center
# 51                 Long Center @ South 1st & Riverside
# 52               Republic Square @ Guadalupe & 4th St.
# 53                                          3rd & West
# 54                                            3rd/West
# 55   State Capitol Visitors Garage @ San Jacinto & ...
# 56    12th/San Jacinto @ State Capitol Visitors Garage
# 57                            San Jacinto & 8th Street
# 58                                     8th/San Jacinto
# 59                              Davis at Rainey Street
# 60                                        Rainey/Davis
# 61                                     Rainey/Driskill
# 62                                    5th & San Marcos
# 63                                         6th/Trinity
# 64                                Trinity & 6th Street
# 65   Electric Drive/Sandra Muraida Way @ Pfluger Pe...
# 66                       Pfluger Bridge @ W 2nd Street
# 67          Barton Springs/Bouldin @ Palmer Auditorium
# 68                                   Palmer Auditorium
# 69                             East 11th/Victory Grill
# 70                   East 11th Street at Victory Grill
# 71                      East 11th St. at Victory Grill
# 72                                East 11th/San Marcos
# 73                          East 11th St. & San Marcos
# 74                              South Congress/Academy
# 75                            South Congress & Academy
# 76                              Red River & 8th Street
# 77                                       8th/Red River
# 78                                 Barton Springs Pool
# 79   Zilker Park at Barton Springs & William Barton...
# 80                                         Zilker Park
# 81                                Riverside @ S. Lamar
# 82                               Riverside/South Lamar
# 83                                   Rainey @ River St
# 84                                Rainey St @ Cummings
# 85                                     Rainey/Cummings
# 86                         Barton Springs @ Kinney Ave
# 87                               Barton Springs/Kinney
# 88                             Toomey Rd @ South Lamar
# 89                         East 6th/Robert T. Martinez
# 90                         East 6th at Robert Martinez
# 91                East 5th/Broadway @ Capital Metro HQ
# 92             Capital Metro HQ - East 5th at Broadway
# 93                                    11th/San Jacinto
# 94                                  11th & San Jacinto
# 95                                   East 4th & Chicon
# 96                                     East 4th/Chicon
# 97                               East 2nd & Pedernales
# 98                                 East 2nd/Pedernales
# 99                                     Guadalupe & 6th
# 100                                       Lavaca & 6th
# 101                                         6th/Lavaca
# 102                Veterans/Atlanta @ MoPac Ped Bridge
# 103           MoPac Pedestrian Bridge @ Veterans Drive
# 104                         East 7th & Pleasant Valley
# 105                                         6th/Brazos
# 106                                       Brazos & 6th
# 107                                    Republic Square
# 108              Republic Square @ Guadalupe & 4th St.
# 109         Republic Square @ Federal Courthouse Plaza
# 110                    4th/Guadalupe @ Republic Square
# 111                  Republic Square @ 5th & Guadalupe
# 112                    5th/Guadalupe @ Republic Square
# 113                                         Pease Park
# 114  South Congress & Barton Springs at the Austin ...
# 115  South Congress/Barton Springs @ The Austin Ame...
# 116                                     6th & Congress
# 117                                       6th/Congress
# 118                                       Nueces & 3rd
# 119                                         3rd/Nueces
# 120                                   13th/San Antonio
# 121                                 13th & San Antonio
# 122                                  Medina & East 6th
# 123                                    East 6th/Medina
# 124                              cesar Chavez/Congress
# 125                              Cesar Chavez/Congress
# 126                            Congress & Cesar Chavez
# 127                                    Henderson & 9th
# 128                                      9th/Henderson
# 129                         Sterzing at Barton Springs
# 130                            Sterzing/Barton Springs
# 131                                     Boardwalk West
# 132                       Lake Austin Blvd @ Deep Eddy
# 133                         Lake Austin Blvd/Deep Eddy
# 134                                Lake Austin/Enfield
# 135                              Lake Austin & Enfield
# 136                                       22nd & Pearl
# 137                                  Rio Grande & 28th
# 138                                    28th/Rio Grande
# 139                                         4th/Sabine
# 140                               Dean Keeton & Whitis
# 141                                 Dean Keeton/Whitis
# 142                                    21st/University
# 143                                  21st & University
# 144                               21st & Speedway @PCL
# 145                                21st/Speedway @ PCL
# 146                   23rd & San Jacinto @ DKR Stadium
# 147                     23rd/San Jacinto @ DKR Stadium
# 148                                      Nueces & 26th
# 149                                        26th/Nueces
# 150                                  23rd & Rio Grande
# 151                                    23rd/Rio Grande
# 152                                       8th & Lavaca
# 153                                         8th/Lavaca
# 154                     South Congress @ Bouldin Creek
# 155                                       5th/Campbell
# 156                                     5th & Campbell
# 157                                   10th & Red River
# 158                                     10th/Red River
# 159                                Rosewood & Angelina
# 160                                  Rosewood/Angelina
# 161                                  Rosewood & Chicon
# 162                                    Rosewood/Chicon
# 163                                      11th & Salina
# 164                                        11th/Salina
# 165                                     6th & Chalmers
# 166                                       6th/Chalmers
# 167                        Hollow Creek & Barton Hills
# 168                          Hollow Creek/Barton Hills
# 169                         Nash Hernandez @ RBJ South
# 170                    Nash Hernandez/East @ RBJ South
# 171              Red River/Cesar Chavez @ The Fairmont
# 172                          Lakeshore @ Austin Hostel
# 173                            Lakeshore/Austin Hostel
# 174                        Lakeshore & Pleasant Valley
# 175                          Lakeshore/Pleasant Valley
# 176                East 5th/Shady @ Eastside Bus Plaza
# 177                                  East 5th/Shady Ln
# 178                                   16th/San Antonio
# 179                                    22.5/Rio Grande
# 180                                         23rd/Pearl
# 181                                   23rd/San Gabriel
# 182                   13th/Trinity @ Waterloo Greenway
# 183                                       13th/Trinity
# 184                                   One Texas Center
# 185                                South Congress/Mary
# 186                                         22nd/Pearl
# 187                                           28th/Rio
# 188                                    Rio Grande/12th
# 189                           Barton Springs/Riverside

# %%
result.shape[0]
# Out:
# 190

# %%
# error ??
# result["Last Date Used"] = pd.to_datetime(result["Last Date Used"])

# %%
result
# Out:
#      Last ID       Last Date Used  \
# 0     1002.0           2014-06-30
# 1     1003.0           2014-06-12
# 2     1004.0  2015-02-26 00:00:00
# 3     1005.0           2014-06-16
# 4     1006.0           2016-10-12
# 5     1008.0           2016-01-29
# 6     2494.0           2019-05-31
# 7     2494.0           2022-11-30
# 8     2495.0           2019-05-31
# 9     2495.0           2022-11-30
# 10    2496.0           2022-11-29
# 11    2496.0           2019-05-31
# 12    2497.0           2022-11-30
# 13    2497.0           2019-05-31
# 14    2498.0  2000-01-01 00:00:00
# 15    2498.0  2022-11-30 00:00:00
# 16    2499.0           2022-11-30
# 17    2499.0           2019-05-31
# 18    2500.0           2016-05-31
# 19    2501.0           2022-11-30
# 20    2501.0           2019-05-29
# 21    2502.0           2019-02-04
# 22    2503.0           2022-11-30
# 23    2503.0           2019-05-31
# 24    2504.0           2022-11-30
# 25    2504.0           2019-05-31
# 26    2536.0           2016-05-30
# 27    2537.0           2022-11-29
# 28    2537.0           2019-05-31
# 29    2538.0           2017-12-30
# 30    2539.0  2000-01-01 00:00:00
# 31    2539.0  2000-01-01 00:00:00
# 32    2539.0           2019-05-31
# 33    2539.0  2014-10-31 00:00:00
# 34    2539.0           2022-11-30
# 35    2539.0  2022-11-30 00:00:00
# 36    2539.0  2019-05-31 00:00:00
# 37    2540.0           2020-04-11
# 38    2540.0           2019-05-31
# 39    2541.0           2017-12-30
# 40    2542.0           2022-11-30
# 41    2544.0           2022-11-30
# 42    2544.0           2019-04-18
# 43    2545.0           2015-12-29
# 44    2546.0           2016-11-28
# 45    2546.0  2015-09-30 00:00:00
# 46    2547.0           2019-05-31
# 47    2547.0           2022-11-30
# 48    2548.0           2022-11-30
# 49    2548.0           2019-05-31
# 50    2549.0           2022-11-30
# 51    2549.0           2019-05-31
# 52    2550.0           2016-07-12
# 53    2552.0           2019-05-31
# 54    2552.0           2022-11-30
# 55    2561.0           2019-05-31
# 56    2561.0           2022-11-30
# 57    2562.0           2019-05-31
# 58    2562.0           2022-11-30
# 59    2563.0           2019-05-31
# 60    2563.0           2022-01-25
# 61    2563.0           2022-11-30
# 62    2564.0           2017-03-03
# 63    2565.0           2022-11-30
# 64    2565.0           2019-05-31
# 65    2566.0           2022-11-30
# 66    2566.0           2019-05-31
# 67    2567.0           2022-11-29
# 68    2567.0           2019-05-31
# 69    2568.0           2022-11-30
# 70    2568.0  2014-10-31 00:00:00
# 71    2568.0           2019-05-31
# 72    2569.0           2022-11-30
# 73    2569.0           2019-05-31
# 74    2570.0           2022-11-30
# 75    2570.0           2019-05-31
# 76    2571.0           2019-05-31
# 77    2571.0           2022-11-30
# 78    2572.0           2022-11-29
# 79    2574.0  2015-08-31 00:00:00
# 80    2574.0           2022-11-29
# 81    2575.0           2019-05-31
# 82    2575.0           2022-11-29
# 83    2576.0           2016-02-22
# 84    2707.0           2019-05-31
# 85    2707.0           2022-11-30
# 86    2711.0           2019-05-31
# 87    2711.0           2022-11-29
# 88    2712.0           2015-12-17
# 89    2822.0           2022-11-29
# 90    2822.0           2019-05-31
# 91    2823.0           2022-11-30
# 92    2823.0           2019-05-30
# 93    3291.0           2022-10-02
# 94    3291.0           2019-05-31
# 95    3292.0           2019-05-31
# 96    3292.0           2022-11-29
# 97    3293.0           2019-05-31
# 98    3293.0           2022-11-30
# 99    3294.0           2017-04-30
# 100   3294.0           2019-05-31
# 101   3294.0           2022-11-30
# 102   3377.0           2022-11-29
# 103   3377.0           2019-05-31
# 104   3381.0           2016-11-29
# 105   3390.0           2022-11-30
# 106   3390.0           2019-05-31
# 107   3455.0  2016-05-31 00:00:00
# 108   3455.0  2016-07-12 00:00:00
# 109   3455.0  2017-08-31 00:00:00
# 110   3455.0  2022-11-30 00:00:00
# 111   3455.0  2019-05-31 00:00:00
# 112   3455.0  2019-10-31 00:00:00
# 113   3464.0           2017-04-25
# 114   3513.0           2019-05-31
# 115   3513.0           2022-11-30
# 116   3619.0           2019-05-31
# 117   3619.0           2022-11-30
# 118   3621.0           2019-05-31
# 119   3621.0           2022-11-30
# 120   3635.0           2020-11-18
# 121   3635.0           2019-05-31
# 122   3660.0           2019-05-31
# 123   3660.0           2022-11-30
# 124   3684.0           2019-12-14
# 125   3684.0           2022-11-30
# 126   3684.0           2019-05-31
# 127   3685.0           2019-05-31
# 128   3685.0           2022-11-30
# 129   3686.0           2019-05-31
# 130   3686.0           2022-11-30
# 131   3687.0           2022-11-30
# 132   3790.0           2019-05-31
# 133   3790.0           2022-11-30
# 134   3791.0           2022-11-30
# 135   3791.0           2019-05-30
# 136   3792.0           2019-05-31
# 137   3793.0           2019-05-31
# 138   3793.0           2022-02-22
# 139   3794.0  2022-11-29 00:00:00
# 140   3795.0           2019-05-30
# 141   3795.0           2022-11-30
# 142   3797.0           2022-11-30
# 143   3797.0           2019-05-31
# 144   3798.0           2019-05-31
# 145   3798.0           2022-11-30
# 146   3799.0           2019-05-31
# 147   3799.0           2022-11-30
# 148   3838.0           2019-05-31
# 149   3838.0           2022-11-30
# 150   3841.0           2019-05-31
# 151   3841.0           2021-09-28
# 152   4047.0           2019-05-31
# 153   4047.0           2022-11-30
# 154   4048.0           2022-11-30
# 155   4050.0           2022-11-30
# 156   4050.0           2019-05-31
# 157   4051.0           2019-05-31
# 158   4051.0           2022-11-30
# 159   4052.0           2019-05-29
# 160   4052.0           2022-11-30
# 161   4054.0           2019-05-27
# 162   4054.0           2022-11-29
# 163   4055.0           2019-05-31
# 164   4055.0           2022-11-30
# 165   4057.0           2019-05-31
# 166   4057.0           2022-11-30
# 167   4058.0           2019-05-31
# 168   4058.0           2022-11-30
# 169   4059.0           2019-05-31
# 170   4059.0           2022-11-30
# 171   4060.0           2022-11-30
# 172   4061.0           2019-05-31
# 173   4061.0           2022-11-30
# 174   4062.0           2019-05-31
# 175   4062.0           2022-11-30
# 176   4699.0           2022-11-27
# 177   4699.0           2020-12-31
# 178   4879.0           2022-11-30
# 179   4938.0           2022-11-30
# 180   7125.0           2022-11-30
# 181   7125.0           2022-05-31
# 182   7131.0           2022-11-30
# 183   7131.0           2022-03-31
# 184   7186.0           2022-11-30
# 185   7187.0           2022-11-30
# 186   7188.0           2022-11-30
# 187   7189.0           2022-11-30
# 188   7190.0           2022-11-30
# 189   7253.0           2022-11-30
#
#                                             Kiosk Name
# 0                                   6th & Navasota St.
# 1                                      8th & Guadalupe
# 2                              Red River @ LBJ Library
# 3                 State Parking Garage @ Brazos & 18th
# 4                                     Zilker Park West
# 5                                         Nueces @ 3rd
# 6                                       2nd & Congress
# 7                                         2nd/Congress
# 8                                       4th & Congress
# 9                                         4th/Congress
# 10                                        8th/Congress
# 11                                      8th & Congress
# 12                   11th/Congress @ The Texas Capitol
# 13                   Capitol Station / Congress & 11th
# 14                              Dean Keeton & Speedway
# 15                                Dean Keeton/Speedway
# 16                              2nd/Lavaca @ City Hall
# 17                            City Hall / Lavaca & 2nd
# 18                                     Republic Square
# 19                                           5th/Bowie
# 20                                         5th & Bowie
# 21                          Barton Springs & Riverside
# 22                                South Congress/James
# 23                              South Congress & James
# 24                            South Congress/Elizabeth
# 25                          South Congress & Elizabeth
# 26                                    Waller & 6th St.
# 27                                            6th/West
# 28                                      West & 6th St.
# 29                     Bullock Museum @ Congress & MLK
# 30                     4th/Neches @ MetroRail Downtown
# 31             Convention Center / 4th St. @ MetroRail
# 32                   Convention Center / 3rd & Trinity
# 33                    Convention Center/ 3rd & Trinity
# 34                 3rd/Trinity @ The Convention Center
# 35                 3rd/Trinity @ The Convention Center
# 36                   Convention Center / 3rd & Trinity
# 37                                      17th/Guadalupe
# 38                                    17th & Guadalupe
# 39                     State Capitol @ 14th & Colorado
# 40                                      Plaza Saltillo
# 41                                 East 6th/Pedernales
# 42                           East 6th & Pedernales St.
# 43                             ACC - Rio Grande & 12th
# 44                            ACC - West & 12th Street
# 45                                   ACC - West & 12th
# 46                                    Guadalupe & 21st
# 47                                      21st/Guadalupe
# 48              Guadalupe/West Mall @ University Co-op
# 49                            UT West Mall @ Guadalupe
# 50                   South 1st/Riverside @ Long Center
# 51                 Long Center @ South 1st & Riverside
# 52               Republic Square @ Guadalupe & 4th St.
# 53                                          3rd & West
# 54                                            3rd/West
# 55   State Capitol Visitors Garage @ San Jacinto & ...
# 56    12th/San Jacinto @ State Capitol Visitors Garage
# 57                            San Jacinto & 8th Street
# 58                                     8th/San Jacinto
# 59                              Davis at Rainey Street
# 60                                        Rainey/Davis
# 61                                     Rainey/Driskill
# 62                                    5th & San Marcos
# 63                                         6th/Trinity
# 64                                Trinity & 6th Street
# 65   Electric Drive/Sandra Muraida Way @ Pfluger Pe...
# 66                       Pfluger Bridge @ W 2nd Street
# 67          Barton Springs/Bouldin @ Palmer Auditorium
# 68                                   Palmer Auditorium
# 69                             East 11th/Victory Grill
# 70                   East 11th Street at Victory Grill
# 71                      East 11th St. at Victory Grill
# 72                                East 11th/San Marcos
# 73                          East 11th St. & San Marcos
# 74                              South Congress/Academy
# 75                            South Congress & Academy
# 76                              Red River & 8th Street
# 77                                       8th/Red River
# 78                                 Barton Springs Pool
# 79   Zilker Park at Barton Springs & William Barton...
# 80                                         Zilker Park
# 81                                Riverside @ S. Lamar
# 82                               Riverside/South Lamar
# 83                                   Rainey @ River St
# 84                                Rainey St @ Cummings
# 85                                     Rainey/Cummings
# 86                         Barton Springs @ Kinney Ave
# 87                               Barton Springs/Kinney
# 88                             Toomey Rd @ South Lamar
# 89                         East 6th/Robert T. Martinez
# 90                         East 6th at Robert Martinez
# 91                East 5th/Broadway @ Capital Metro HQ
# 92             Capital Metro HQ - East 5th at Broadway
# 93                                    11th/San Jacinto
# 94                                  11th & San Jacinto
# 95                                   East 4th & Chicon
# 96                                     East 4th/Chicon
# 97                               East 2nd & Pedernales
# 98                                 East 2nd/Pedernales
# 99                                     Guadalupe & 6th
# 100                                       Lavaca & 6th
# 101                                         6th/Lavaca
# 102                Veterans/Atlanta @ MoPac Ped Bridge
# 103           MoPac Pedestrian Bridge @ Veterans Drive
# 104                         East 7th & Pleasant Valley
# 105                                         6th/Brazos
# 106                                       Brazos & 6th
# 107                                    Republic Square
# 108              Republic Square @ Guadalupe & 4th St.
# 109         Republic Square @ Federal Courthouse Plaza
# 110                    4th/Guadalupe @ Republic Square
# 111                  Republic Square @ 5th & Guadalupe
# 112                    5th/Guadalupe @ Republic Square
# 113                                         Pease Park
# 114  South Congress & Barton Springs at the Austin ...
# 115  South Congress/Barton Springs @ The Austin Ame...
# 116                                     6th & Congress
# 117                                       6th/Congress
# 118                                       Nueces & 3rd
# 119                                         3rd/Nueces
# 120                                   13th/San Antonio
# 121                                 13th & San Antonio
# 122                                  Medina & East 6th
# 123                                    East 6th/Medina
# 124                              cesar Chavez/Congress
# 125                              Cesar Chavez/Congress
# 126                            Congress & Cesar Chavez
# 127                                    Henderson & 9th
# 128                                      9th/Henderson
# 129                         Sterzing at Barton Springs
# 130                            Sterzing/Barton Springs
# 131                                     Boardwalk West
# 132                       Lake Austin Blvd @ Deep Eddy
# 133                         Lake Austin Blvd/Deep Eddy
# 134                                Lake Austin/Enfield
# 135                              Lake Austin & Enfield
# 136                                       22nd & Pearl
# 137                                  Rio Grande & 28th
# 138                                    28th/Rio Grande
# 139                                         4th/Sabine
# 140                               Dean Keeton & Whitis
# 141                                 Dean Keeton/Whitis
# 142                                    21st/University
# 143                                  21st & University
# 144                               21st & Speedway @PCL
# 145                                21st/Speedway @ PCL
# 146                   23rd & San Jacinto @ DKR Stadium
# 147                     23rd/San Jacinto @ DKR Stadium
# 148                                      Nueces & 26th
# 149                                        26th/Nueces
# 150                                  23rd & Rio Grande
# 151                                    23rd/Rio Grande
# 152                                       8th & Lavaca
# 153                                         8th/Lavaca
# 154                     South Congress @ Bouldin Creek
# 155                                       5th/Campbell
# 156                                     5th & Campbell
# 157                                   10th & Red River
# 158                                     10th/Red River
# 159                                Rosewood & Angelina
# 160                                  Rosewood/Angelina
# 161                                  Rosewood & Chicon
# 162                                    Rosewood/Chicon
# 163                                      11th & Salina
# 164                                        11th/Salina
# 165                                     6th & Chalmers
# 166                                       6th/Chalmers
# 167                        Hollow Creek & Barton Hills
# 168                          Hollow Creek/Barton Hills
# 169                         Nash Hernandez @ RBJ South
# 170                    Nash Hernandez/East @ RBJ South
# 171              Red River/Cesar Chavez @ The Fairmont
# 172                          Lakeshore @ Austin Hostel
# 173                            Lakeshore/Austin Hostel
# 174                        Lakeshore & Pleasant Valley
# 175                          Lakeshore/Pleasant Valley
# 176                East 5th/Shady @ Eastside Bus Plaza
# 177                                  East 5th/Shady Ln
# 178                                   16th/San Antonio
# 179                                    22.5/Rio Grande
# 180                                         23rd/Pearl
# 181                                   23rd/San Gabriel
# 182                   13th/Trinity @ Waterloo Greenway
# 183                                       13th/Trinity
# 184                                   One Texas Center
# 185                                South Congress/Mary
# 186                                         22nd/Pearl
# 187                                           28th/Rio
# 188                                    Rio Grande/12th
# 189                           Barton Springs/Riverside

# %%
# MAKE THE UPDATES in trips datasets
# searching for the name and updating the kiosk ID numbers throughout - this should handle anything labeled 
# incorrectly or not labeled 

for name, kiosk_id in zip(result['Kiosk Name'],result['Last ID']):

    trips.loc[trips['Checkout Kiosk'] == name, 'Checkout Kiosk ID'] = kiosk_id
    trips.loc[trips['Return Kiosk'] == name, 'Return Kiosk ID'] = kiosk_id
    kiosk.loc[kiosk['Kiosk Name']== name, 'Kiosk ID'] = kiosk_id

# %%
for kiosk_id in result['Last ID'].unique():
    if len(result.loc[result['Last ID']== kiosk_id])>1:
        temp = result.loc[result['Last ID'] == kiosk_id].sort_values("Last Date Used")
        last_name = temp.iloc[-1]['Kiosk Name']
        
        trips.loc[trips['Checkout Kiosk ID'] == kiosk_id, 'Checkout Kiosk'] = last_name
        trips.loc[trips['Return Kiosk ID'] == kiosk_id, 'Return Kiosk'] = last_name
        kiosk.loc[kiosk['Kiosk ID']== kiosk_id, 'Kiosk Name'] = last_name
        
        last_name = ' '

# %%
result1 = result.sort_values(['Last ID','Last Date Used']).drop_duplicates(subset = ['Last ID'], keep = 'last')
result1
# Out:
#      Last ID       Last Date Used  \
# 0     1002.0           2014-06-30
# 1     1003.0           2014-06-12
# 2     1004.0  2015-02-26 00:00:00
# 3     1005.0           2014-06-16
# 4     1006.0           2016-10-12
# 5     1008.0           2016-01-29
# 7     2494.0           2022-11-30
# 9     2495.0           2022-11-30
# 10    2496.0           2022-11-29
# 12    2497.0           2022-11-30
# 15    2498.0  2022-11-30 00:00:00
# 16    2499.0           2022-11-30
# 18    2500.0           2016-05-31
# 19    2501.0           2022-11-30
# 21    2502.0           2019-02-04
# 22    2503.0           2022-11-30
# 24    2504.0           2022-11-30
# 26    2536.0           2016-05-30
# 27    2537.0           2022-11-29
# 29    2538.0           2017-12-30
# 35    2539.0  2022-11-30 00:00:00
# 37    2540.0           2020-04-11
# 39    2541.0           2017-12-30
# 40    2542.0           2022-11-30
# 41    2544.0           2022-11-30
# 43    2545.0           2015-12-29
# 44    2546.0           2016-11-28
# 47    2547.0           2022-11-30
# 48    2548.0           2022-11-30
# 50    2549.0           2022-11-30
# 52    2550.0           2016-07-12
# 54    2552.0           2022-11-30
# 56    2561.0           2022-11-30
# 58    2562.0           2022-11-30
# 61    2563.0           2022-11-30
# 62    2564.0           2017-03-03
# 63    2565.0           2022-11-30
# 65    2566.0           2022-11-30
# 67    2567.0           2022-11-29
# 69    2568.0           2022-11-30
# 72    2569.0           2022-11-30
# 74    2570.0           2022-11-30
# 77    2571.0           2022-11-30
# 78    2572.0           2022-11-29
# 80    2574.0           2022-11-29
# 82    2575.0           2022-11-29
# 83    2576.0           2016-02-22
# 85    2707.0           2022-11-30
# 87    2711.0           2022-11-29
# 88    2712.0           2015-12-17
# 89    2822.0           2022-11-29
# 91    2823.0           2022-11-30
# 93    3291.0           2022-10-02
# 96    3292.0           2022-11-29
# 98    3293.0           2022-11-30
# 101   3294.0           2022-11-30
# 102   3377.0           2022-11-29
# 104   3381.0           2016-11-29
# 105   3390.0           2022-11-30
# 110   3455.0  2022-11-30 00:00:00
# 113   3464.0           2017-04-25
# 115   3513.0           2022-11-30
# 117   3619.0           2022-11-30
# 119   3621.0           2022-11-30
# 120   3635.0           2020-11-18
# 123   3660.0           2022-11-30
# 125   3684.0           2022-11-30
# 128   3685.0           2022-11-30
# 130   3686.0           2022-11-30
# 131   3687.0           2022-11-30
# 133   3790.0           2022-11-30
# 134   3791.0           2022-11-30
# 136   3792.0           2019-05-31
# 138   3793.0           2022-02-22
# 139   3794.0  2022-11-29 00:00:00
# 141   3795.0           2022-11-30
# 142   3797.0           2022-11-30
# 145   3798.0           2022-11-30
# 147   3799.0           2022-11-30
# 149   3838.0           2022-11-30
# 151   3841.0           2021-09-28
# 153   4047.0           2022-11-30
# 154   4048.0           2022-11-30
# 155   4050.0           2022-11-30
# 158   4051.0           2022-11-30
# 160   4052.0           2022-11-30
# 162   4054.0           2022-11-29
# 164   4055.0           2022-11-30
# 166   4057.0           2022-11-30
# 168   4058.0           2022-11-30
# 170   4059.0           2022-11-30
# 171   4060.0           2022-11-30
# 173   4061.0           2022-11-30
# 175   4062.0           2022-11-30
# 176   4699.0           2022-11-27
# 178   4879.0           2022-11-30
# 179   4938.0           2022-11-30
# 180   7125.0           2022-11-30
# 182   7131.0           2022-11-30
# 184   7186.0           2022-11-30
# 185   7187.0           2022-11-30
# 186   7188.0           2022-11-30
# 187   7189.0           2022-11-30
# 188   7190.0           2022-11-30
# 189   7253.0           2022-11-30
#
#                                             Kiosk Name
# 0                                   6th & Navasota St.
# 1                                      8th & Guadalupe
# 2                              Red River @ LBJ Library
# 3                 State Parking Garage @ Brazos & 18th
# 4                                     Zilker Park West
# 5                                         Nueces @ 3rd
# 7                                         2nd/Congress
# 9                                         4th/Congress
# 10                                        8th/Congress
# 12                   11th/Congress @ The Texas Capitol
# 15                                Dean Keeton/Speedway
# 16                              2nd/Lavaca @ City Hall
# 18                                     Republic Square
# 19                                           5th/Bowie
# 21                          Barton Springs & Riverside
# 22                                South Congress/James
# 24                            South Congress/Elizabeth
# 26                                    Waller & 6th St.
# 27                                            6th/West
# 29                     Bullock Museum @ Congress & MLK
# 35                 3rd/Trinity @ The Convention Center
# 37                                      17th/Guadalupe
# 39                     State Capitol @ 14th & Colorado
# 40                                      Plaza Saltillo
# 41                                 East 6th/Pedernales
# 43                             ACC - Rio Grande & 12th
# 44                            ACC - West & 12th Street
# 47                                      21st/Guadalupe
# 48              Guadalupe/West Mall @ University Co-op
# 50                   South 1st/Riverside @ Long Center
# 52               Republic Square @ Guadalupe & 4th St.
# 54                                            3rd/West
# 56    12th/San Jacinto @ State Capitol Visitors Garage
# 58                                     8th/San Jacinto
# 61                                     Rainey/Driskill
# 62                                    5th & San Marcos
# 63                                         6th/Trinity
# 65   Electric Drive/Sandra Muraida Way @ Pfluger Pe...
# 67          Barton Springs/Bouldin @ Palmer Auditorium
# 69                             East 11th/Victory Grill
# 72                                East 11th/San Marcos
# 74                              South Congress/Academy
# 77                                       8th/Red River
# 78                                 Barton Springs Pool
# 80                                         Zilker Park
# 82                               Riverside/South Lamar
# 83                                   Rainey @ River St
# 85                                     Rainey/Cummings
# 87                               Barton Springs/Kinney
# 88                             Toomey Rd @ South Lamar
# 89                         East 6th/Robert T. Martinez
# 91                East 5th/Broadway @ Capital Metro HQ
# 93                                    11th/San Jacinto
# 96                                     East 4th/Chicon
# 98                                 East 2nd/Pedernales
# 101                                         6th/Lavaca
# 102                Veterans/Atlanta @ MoPac Ped Bridge
# 104                         East 7th & Pleasant Valley
# 105                                         6th/Brazos
# 110                    4th/Guadalupe @ Republic Square
# 113                                         Pease Park
# 115  South Congress/Barton Springs @ The Austin Ame...
# 117                                       6th/Congress
# 119                                         3rd/Nueces
# 120                                   13th/San Antonio
# 123                                    East 6th/Medina
# 125                              Cesar Chavez/Congress
# 128                                      9th/Henderson
# 130                            Sterzing/Barton Springs
# 131                                     Boardwalk West
# 133                         Lake Austin Blvd/Deep Eddy
# 134                                Lake Austin/Enfield
# 136                                       22nd & Pearl
# 138                                    28th/Rio Grande
# 139                                         4th/Sabine
# 141                                 Dean Keeton/Whitis
# 142                                    21st/University
# 145                                21st/Speedway @ PCL
# 147                     23rd/San Jacinto @ DKR Stadium
# 149                                        26th/Nueces
# 151                                    23rd/Rio Grande
# 153                                         8th/Lavaca
# 154                     South Congress @ Bouldin Creek
# 155                                       5th/Campbell
# 158                                     10th/Red River
# 160                                  Rosewood/Angelina
# 162                                    Rosewood/Chicon
# 164                                        11th/Salina
# 166                                       6th/Chalmers
# 168                          Hollow Creek/Barton Hills
# 170                    Nash Hernandez/East @ RBJ South
# 171              Red River/Cesar Chavez @ The Fairmont
# 173                            Lakeshore/Austin Hostel
# 175                          Lakeshore/Pleasant Valley
# 176                East 5th/Shady @ Eastside Bus Plaza
# 178                                   16th/San Antonio
# 179                                    22.5/Rio Grande
# 180                                         23rd/Pearl
# 182                   13th/Trinity @ Waterloo Greenway
# 184                                   One Texas Center
# 185                                South Congress/Mary
# 186                                         22nd/Pearl
# 187                                           28th/Rio
# 188                                    Rio Grande/12th
# 189                           Barton Springs/Riverside

# %% [markdown]
# ## 5. Look at the Kiosk data for duplicates

# %%
kiosk.shape[0]
# Out:
# 102

# %%
kiosk['Kiosk ID'].value_counts()
# Out:
# 3455    3
# 3294    2
# 3685    1
# 1002    1
# 3293    1
# 3292    1
# 3291    1
# 4058    1
# 4057    1
# 2822    1
# 3798    1
# 3797    1
# 4052    1
# 3795    1
# 4050    1
# 3793    1
# 3792    1
# 3791    1
# 3790    1
# 3660    1
# 4062    1
# 2504    1
# 2503    1
# 3684    1
# 3686    1
# 2501    1
# 3687    1
# 2541    1
# 2537    1
# 4048    1
# 4047    1
# 2552    1
# 3841    1
# 7187    1
# 2549    1
# 2548    1
# 2547    1
# 2546    1
# 2545    1
# 2544    1
# 1008    1
# 2542    1
# 4060    1
# 2540    1
# 2539    1
# 2538    1
# 1001    1
# 2536    1
# 2502    1
# 2561    1
# 2562    1
# 111     1
# 1111    1
# 3464    1
# 4059    1
# 2567    1
# 2711    1
# 2707    1
# 4061    1
# 1004    1
# 2576    1
# 2575    1
# 2574    1
# 2572    1
# 2571    1
# 2570    1
# 2569    1
# 2568    1
# 2823    1
# 2566    1
# 2565    1
# 2564    1
# 2563    1
# 3619    1
# 3621    1
# 2499    1
# 1003    1
# 2498    1
# 2497    1
# 2496    1
# 2495    1
# 2494    1
# 4699    1
# 2712    1
# 1006    1
# 3513    1
# 4879    1
# 4055    1
# 3381    1
# 4054    1
# 3635    1
# 1005    1
# 3377    1
# 3838    1
# 11      1
# 3794    1
# 3390    1
# 4051    1
# 3799    1
# Name: Kiosk ID, dtype: int64

# %%
kiosk.loc[kiosk['Kiosk ID']==3455]
# Out:
#     Kiosk ID                       Kiosk Name Kiosk Status  \
# 6       3455  4th/Guadalupe @ Republic Square       closed
# 26      3455  4th/Guadalupe @ Republic Square       active
# 92      3455  4th/Guadalupe @ Republic Square       closed
#
#                    Location                   Address Alternate Name  \
# 6     (30.26753, -97.74805)  Federal Courthouse Plaza            NaN
# 26  (30.267263, -97.747144)                       NaN            NaN
# 92    (30.26751, -97.74802)          425 W 4th Street            NaN
#
#     City Asset Number Property Type  Number of Docks   Power Type  \
# 6             16741.0      sidewalk             13.0  non-metered
# 26                NaN      sidewalk             17.0        solar
# 92                NaN           NaN              NaN          NaN
#
#     Footprint Length  Footprint Width                        Notes  \
# 6               40.0              5.0  Moved back to 4th/Guadalupe
# 26              30.0              5.0                          NaN
# 92               NaN              NaN                          NaN
#
#     Council District  Image           Modified Date
# 6                  9    NaN  03/04/2022 10:24:00 AM
# 26                 9    NaN  03/04/2022 10:28:00 AM
# 92                 9    NaN  01/04/2021 12:00:00 AM

# %%
kiosk.loc[kiosk['Kiosk ID']==3294]
# Out:
#     Kiosk ID  Kiosk Name Kiosk Status                 Location  \
# 4       3294  6th/Lavaca       active  (30.268887, -97.745242)
# 90      3294  6th/Lavaca       closed    (30.26889, -97.74525)
#
#            Address Alternate Name  City Asset Number Property Type  \
# 4   601 Lavaca St.            NaN            32515.0      sidewalk
# 90  601 Lavaca St.            NaN                NaN           NaN
#
#     Number of Docks Power Type  Footprint Length  Footprint Width  \
# 4              12.0      solar              25.0              8.0
# 90              NaN        NaN               NaN              NaN
#
#                       Notes  Council District  Image           Modified Date
# 4   double sided, remeasure                 9    NaN  03/04/2022 10:21:00 AM
# 90                      NaN                 9    NaN  01/04/2021 12:00:00 AM

# %%
kiosk = kiosk.drop([6,92,90])

# %%
kiosk.loc[kiosk['Kiosk ID']==3294]
# Out:
#    Kiosk ID  Kiosk Name Kiosk Status                 Location         Address  \
# 4      3294  6th/Lavaca       active  (30.268887, -97.745242)  601 Lavaca St.
#
#   Alternate Name  City Asset Number Property Type  Number of Docks Power Type  \
# 4            NaN            32515.0      sidewalk             12.0      solar
#
#    Footprint Length  Footprint Width                    Notes  \
# 4              25.0              8.0  double sided, remeasure
#
#    Council District  Image           Modified Date
# 4                 9    NaN  03/04/2022 10:21:00 AM

# %%
kiosk.loc[kiosk['Kiosk ID']==3455]
# Out:
#     Kiosk ID                       Kiosk Name Kiosk Status  \
# 26      3455  4th/Guadalupe @ Republic Square       active
#
#                    Location Address Alternate Name  City Asset Number  \
# 26  (30.267263, -97.747144)     NaN            NaN                NaN
#
#    Property Type  Number of Docks Power Type  Footprint Length  \
# 26      sidewalk             17.0      solar              30.0
#
#     Footprint Width Notes  Council District  Image           Modified Date
# 26              5.0   NaN                 9    NaN  03/04/2022 10:28:00 AM

# %% [markdown]
# ## 6. Identify kiosk IDs that are in the Trips dataset but NOT the Kiosk dataset

# %%
# code to examine stuff
# Republic Square @ 5th & Guadalupe
# trips.loc[trips["Checkout Kiosk"].str.contains("Republic Square"),"Checkout Kiosk"].unique()

# %%
# Identify kiosk IDs that are in the trips dataset but NOT the Kiosk dataset
# essentially looking for new or updated kiosk IDs

for checkout_id in trips['Checkout Kiosk ID'].unique():   
    
    if checkout_id not in kiosk['Kiosk ID'].unique():
        
        print(checkout_id, ": this id is NOT in the kiosk dataset.")
        
        if checkout_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",checkout_id," : ", result1[result1['Last ID']==checkout_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Checkout Kiosk ID']==checkout_id]['Checkout Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []
#
#
# 7188.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7188.0  :  ['22nd/Pearl']
# all names found in trips:  ['22nd/Pearl']
# Trip dataset - Kiosk Name:  22nd/Pearl
# Kiosk dataset - Kiosk ID/Name:  3792 22nd & Pearl  %:  0.82
#
#
# 4938.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  4938.0  :  ['22.5/Rio Grande']
# all names found in trips:  ['22.5/Rio Grande']
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  3793 28th/Rio Grande  %:  0.8
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  3841 23rd/Rio Grande  %:  0.8
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  11 22nd 1/2 & Rio Grande  %:  0.72
#
#
# 7125.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7125.0  :  ['23rd/Pearl']
# all names found in trips:  ['23rd/Pearl']
#
#
# 7131.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7131.0  :  ['13th/Trinity @ Waterloo Greenway']
# all names found in trips:  ['13th/Trinity @ Waterloo Greenway']
#
#
# 7186.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7186.0  :  ['One Texas Center']
# all names found in trips:  ['One Texas Center']
#
#
# 7190.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7190.0  :  ['Rio Grande/12th']
# all names found in trips:  ['Rio Grande/12th']
# Trip dataset - Kiosk Name:  Rio Grande/12th
# Kiosk dataset - Kiosk ID/Name:  2545 ACC - Rio Grande & 12th  %:  0.74
#
#
# 7189.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7189.0  :  ['28th/Rio']
# all names found in trips:  ['28th/Rio']
#
#
# 7253.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7253.0  :  ['Barton Springs/Riverside']
# all names found in trips:  ['Barton Springs/Riverside']
# Trip dataset - Kiosk Name:  Barton Springs/Riverside
# Kiosk dataset - Kiosk ID/Name:  2502 Barton Springs & Riverside  %:  0.92
# Trip dataset - Kiosk Name:  Barton Springs/Riverside
# Kiosk dataset - Kiosk ID/Name:  2711 Barton Springs/Kinney  %:  0.76

# %%
# Identify kiosk IDs that are in the Trips dataset but NOT the Kiosk dataset
for return_id in trips['Return Kiosk ID'].unique():   
    
    if return_id not in kiosk['Kiosk ID'].unique():
        
        print(return_id, ": this id is NOT in the kiosk dataset.")
        
        if return_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",return_id," : ", result1[result1['Last ID']==return_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Return Kiosk ID']==return_id]['Return Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []
#
#
# 7188.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7188.0  :  ['22nd/Pearl']
# all names found in trips:  ['22nd/Pearl']
# Trip dataset - Kiosk Name:  22nd/Pearl
# Kiosk dataset - Kiosk ID/Name:  3792 22nd & Pearl  %:  0.82
#
#
# 7189.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7189.0  :  ['28th/Rio']
# all names found in trips:  ['28th/Rio']
#
#
# 4938.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  4938.0  :  ['22.5/Rio Grande']
# all names found in trips:  ['22.5/Rio Grande']
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  3793 28th/Rio Grande  %:  0.8
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  3841 23rd/Rio Grande  %:  0.8
# Trip dataset - Kiosk Name:  22.5/Rio Grande
# Kiosk dataset - Kiosk ID/Name:  11 22nd 1/2 & Rio Grande  %:  0.72
#
#
# 7131.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7131.0  :  ['13th/Trinity @ Waterloo Greenway']
# all names found in trips:  ['13th/Trinity @ Waterloo Greenway']
#
#
# 7125.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7125.0  :  ['23rd/Pearl']
# all names found in trips:  ['23rd/Pearl']
#
#
# 7186.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7186.0  :  ['One Texas Center']
# all names found in trips:  ['One Texas Center']
#
#
# 7190.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7190.0  :  ['Rio Grande/12th']
# all names found in trips:  ['Rio Grande/12th']
# Trip dataset - Kiosk Name:  Rio Grande/12th
# Kiosk dataset - Kiosk ID/Name:  2545 ACC - Rio Grande & 12th  %:  0.74
#
#
# 7253.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  7253.0  :  ['Barton Springs/Riverside']
# all names found in trips:  ['Barton Springs/Riverside']
# Trip dataset - Kiosk Name:  Barton Springs/Riverside
# Kiosk dataset - Kiosk ID/Name:  2502 Barton Springs & Riverside  %:  0.92
# Trip dataset - Kiosk Name:  Barton Springs/Riverside
# Kiosk dataset - Kiosk ID/Name:  2711 Barton Springs/Kinney  %:  0.76

# %% [markdown]
# # Data Cleaning - "kiosk" dataset - Adding two kiosks

# %% [markdown]
# The "trips" dataset included trips from kiosks that were NOT in the "kiosk" dataset, to address this mismatch - we added new kiosk rows to the "kiosk" dataset

# %%
kiosk.columns
# Out:
# Index(['Kiosk ID', 'Kiosk Name', 'Kiosk Status', 'Location', 'Address',
#        'Alternate Name', 'City Asset Number', 'Property Type',
#        'Number of Docks', 'Power Type', 'Footprint Length', 'Footprint Width',
#        'Notes', 'Council District', 'Image', 'Modified Date'],
#       dtype='object')

# %%
# New dataset includes these kiosks

# One Texas Center NOT IN kiosk dataset, 
  # in the trips dataset, this kiosk is IDed as 7186, 
# Lat Lon (got from Google based on location on stations map)
# https://austin.bcycle.com/stations
row1 = {'Kiosk ID': 7186, 'Kiosk Name': 'One Texas Center', 'Kiosk Status': 'Unknown','Location': '(30.25752616374899, -97.74896370141833)','Address': '400 Haywood Ave','Alternate Name': '','City Asset Number': '','Property Type': '','Number of Docks': '','Power Type': '','Footprint Length': '','Footprint Width': '','Notes': '','Council District': 9,'Image': '','Modified Date': 'Mandy 2022-07-26'}
kiosk = kiosk.append(row1, ignore_index = True)

# One Texas Center NOT IN kiosk dataset, 
  # in the trips dataset, this kiosk is IDed as 7186, 
# Lat Lon (got from Google based on location on stations map)
# https://austin.bcycle.com/stations
row1 = {'Kiosk ID': 7189, 'Kiosk Name': '28th/Rio', 'Kiosk Status': 'Unknown','Location': '(30.293172940393987, -97.74409660233584)','Address': '2711 Rio Grande Street','Alternate Name': '','City Asset Number': '','Property Type': '','Number of Docks': '','Power Type': '','Footprint Length': '','Footprint Width': '','Notes': '','Council District': 9,'Image': '','Modified Date': 'Mandy 2022-12-28'}
kiosk = kiosk.append(row1, ignore_index = True)

# adding two more
row1 = {'Kiosk ID': 7125, 'Kiosk Name': '23rd/Pearl', 'Kiosk Status': 'Unknown','Location': '(30.287268378033133, -97.74658031642245)','Address': '905 W 23rd St','Alternate Name': '','City Asset Number': '','Property Type': '','Number of Docks': '','Power Type': '','Footprint Length': '','Footprint Width': '','Notes': '','Council District': 9,'Image': '','Modified Date': 'Mandy 2023-01-04'}
kiosk = kiosk.append(row1, ignore_index = True)
row1 = {'Kiosk ID': 7131, 'Kiosk Name': '13th/Trinity @ Waterloo Greenway', 'Kiosk Status': 'Unknown','Location': '(30.274144170275143, -97.73658827463835)','Address': '910 Trinity Street','Alternate Name': '','City Asset Number': '','Property Type': '','Number of Docks': '','Power Type': '','Footprint Length': '','Footprint Width': '','Notes': '','Council District': 9,'Image': '','Modified Date': 'Mandy 2022-12-28'}
kiosk = kiosk.append(row1, ignore_index = True)

# %%
# Updating some kiosk rows
kiosk.loc[kiosk['Kiosk Name'] == '22nd & Pearl', 'Kiosk ID'] = 7188
kiosk.loc[kiosk['Kiosk Name'] == '22nd & Pearl', 'Kiosk Name'] = '22nd/Pearl'

kiosk.loc[kiosk['Kiosk Name'] == '22nd 1/2 & Rio Grande', 'Kiosk ID'] = 4938
kiosk.loc[kiosk['Kiosk Name'] == '22nd 1/2 & Rio Grande', 'Kiosk Name'] = '22.5/Rio Grande'

kiosk.loc[kiosk['Kiosk Name'] == 'ACC - Rio Grande & 12th', 'Kiosk ID'] = 7190
kiosk.loc[kiosk['Kiosk Name'] == 'ACC - Rio Grande & 12th', 'Kiosk Name'] = 'Rio Grande/12th'

kiosk.loc[kiosk['Kiosk Name'] == 'Barton Springs & Riverside', 'Kiosk ID'] = 7253
kiosk.loc[kiosk['Kiosk Name'] == 'Barton Springs & Riverside', 'Kiosk Name'] = 'Barton Springs/Riverside'

#kiosk.loc[kiosk['Kiosk Name'] == 'South Congress/Mary', 'Kiosk ID'] = 7187 # name doesn't need to be updated

# %%
# testing if the row add worked
kiosk[kiosk['Kiosk ID']== 7188]
# Out:
#     Kiosk ID  Kiosk Name Kiosk Status             Location      Address  \
# 65      7188  22nd/Pearl       active  (30.2853, -97.7467)  900 W. 22nd
#
#    Alternate Name City Asset Number         Property Type Number of Docks  \
# 65            NaN           32669.0  undetermined_parking            13.0
#
#    Power Type Footprint Length Footprint Width Notes  Council District Image  \
# 65      solar             40.0             5.0   NaN                 9   NaN
#
#              Modified Date
# 65  01/04/2021 12:00:00 AM

# %%
# Identify kiosk IDs that are in the trips dataset but NOT the Kiosk dataset
# essentially looking for new or updated kiosk IDs

for checkout_id in trips['Checkout Kiosk ID'].unique():   
    
    if checkout_id not in kiosk['Kiosk ID'].unique():
        
        print(checkout_id, ": this id is NOT in the kiosk dataset.")
        
        if checkout_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",checkout_id," : ", result1[result1['Last ID']==checkout_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Checkout Kiosk ID']==checkout_id]['Checkout Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# 2545.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  2545.0  :  ['ACC - Rio Grande & 12th']
# all names found in trips:  ['ACC - Rio Grande & 12th']
# Trip dataset - Kiosk Name:  ACC - Rio Grande & 12th
# Kiosk dataset - Kiosk ID/Name:  7190 Rio Grande/12th  %:  0.74
#
#
# 2502.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  2502.0  :  ['Barton Springs & Riverside']
# all names found in trips:  ['Barton Springs & Riverside']
# Trip dataset - Kiosk Name:  Barton Springs & Riverside
# Kiosk dataset - Kiosk ID/Name:  7253 Barton Springs/Riverside  %:  0.92
#
#
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []
#
#
# 3792.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  3792.0  :  ['22nd & Pearl']
# all names found in trips:  ['22nd & Pearl']
# Trip dataset - Kiosk Name:  22nd & Pearl
# Kiosk dataset - Kiosk ID/Name:  7188 22nd/Pearl  %:  0.82

# %%
# Identify kiosk IDs that are in the Trips dataset but NOT the Kiosk dataset
for return_id in trips['Return Kiosk ID'].unique():   
    
    if return_id not in kiosk['Kiosk ID'].unique():
        
        print(return_id, ": this id is NOT in the kiosk dataset.")
        
        if return_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",return_id," : ", result1[result1['Last ID']==return_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Return Kiosk ID']==return_id]['Return Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# 2545.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  2545.0  :  ['ACC - Rio Grande & 12th']
# all names found in trips:  ['ACC - Rio Grande & 12th']
# Trip dataset - Kiosk Name:  ACC - Rio Grande & 12th
# Kiosk dataset - Kiosk ID/Name:  7190 Rio Grande/12th  %:  0.74
#
#
# 2502.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  2502.0  :  ['Barton Springs & Riverside']
# all names found in trips:  ['Barton Springs & Riverside']
# Trip dataset - Kiosk Name:  Barton Springs & Riverside
# Kiosk dataset - Kiosk ID/Name:  7253 Barton Springs/Riverside  %:  0.92
#
#
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []
#
#
# 3792.0 : this id is NOT in the kiosk dataset.
# but it is in result1....
# all names found in result1:  3792.0  :  ['22nd & Pearl']
# all names found in trips:  ['22nd & Pearl']
# Trip dataset - Kiosk Name:  22nd & Pearl
# Kiosk dataset - Kiosk ID/Name:  7188 22nd/Pearl  %:  0.82

# %%
# Update these in the trips dataset

trips.loc[trips['Checkout Kiosk ID'] == 3792, 'Checkout Kiosk ID'] = 7188
trips.loc[trips['Return Kiosk ID'] == 3792, 'Return Kiosk ID'] = 7188
trips.loc[trips['Checkout Kiosk ID'] == 3792, 'Checkout Kiosk'] = '22nd/Pearl'
trips.loc[trips['Return Kiosk ID'] == 3792, 'Return Kiosk'] = '22nd/Pearl'

trips.loc[trips['Checkout Kiosk ID'] == 2545, 'Checkout Kiosk ID'] = 7190
trips.loc[trips['Return Kiosk ID'] == 2545, 'Return Kiosk ID'] = 7190
trips.loc[trips['Checkout Kiosk ID'] == 2545, 'Checkout Kiosk'] = 'Rio Grande/12th'
trips.loc[trips['Return Kiosk ID'] == 2545, 'Return Kiosk'] = 'Rio Grande/12th'

trips.loc[trips['Checkout Kiosk ID'] == 2502, 'Checkout Kiosk ID'] = 7253
trips.loc[trips['Return Kiosk ID'] == 2502, 'Return Kiosk ID'] = 7253
trips.loc[trips['Checkout Kiosk ID'] == 2502, 'Checkout Kiosk'] = 'Barton Springs/Riverside'
trips.loc[trips['Return Kiosk ID'] == 2502, 'Return Kiosk'] = 'Barton Springs/Riverside'

# %%
# Identify kiosk IDs that are in the trips dataset but NOT the Kiosk dataset
# essentially looking for new or updated kiosk IDs

for checkout_id in trips['Checkout Kiosk ID'].unique():   
    
    if checkout_id not in kiosk['Kiosk ID'].unique():
        
        print(checkout_id, ": this id is NOT in the kiosk dataset.")
        
        if checkout_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",checkout_id," : ", result1[result1['Last ID']==checkout_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Checkout Kiosk ID']==checkout_id]['Checkout Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []

# %%
# Identify kiosk IDs that are in the Trips dataset but NOT the Kiosk dataset
for return_id in trips['Return Kiosk ID'].unique():   
    
    if return_id not in kiosk['Kiosk ID'].unique():
        
        print(return_id, ": this id is NOT in the kiosk dataset.")
        
        if return_id in result1["Last ID"].unique():
            print("but it is in result1....")
            print("all names found in result1: ",return_id," : ", result1[result1['Last ID']==return_id]['Kiosk Name'].unique())
        
        trips_all_names = trips[trips['Return Kiosk ID']==return_id]['Return Kiosk'].unique()
        print("all names found in trips: ", trips_all_names)
        
        for name in trips_all_names:
            for kiosk_name, kiosk_id in zip(kiosk['Kiosk Name'],kiosk['Kiosk ID']):
           
                if similar(name, kiosk_name) > 0.70:
                    print("Trip dataset - Kiosk Name: ", name)
                    print("Kiosk dataset - Kiosk ID/Name: ", kiosk_id, kiosk_name, " %: ",round(similar(name, kiosk_name),2))
                                   
        print('\n')
# Out:
# nan : this id is NOT in the kiosk dataset.
# all names found in trips:  []

# %% [markdown]
# ## 3. Identify the kiosk IDs that have MULTIPLE kiosk names

# %% [markdown]
# 1. CHECKOUT KIOSK IDS

# %%
nnames = []
for checkout_id in trips['Checkout Kiosk ID'].unique():
    all_names = trips[trips['Checkout Kiosk ID']==checkout_id]['Checkout Kiosk'].unique()
    nnames.append(len(all_names))

    if len(all_names) == 2 and similar(all_names[0],all_names[1]) < 0.50:
        print("Trip Kiosk ID - ", checkout_id)
        print(len(all_names),": ", all_names)        
        print("similarity: ", round(similar(all_names[0],all_names[1]),4),"\n")

# %%
nnames = []
for checkout_id in trips['Checkout Kiosk ID'].unique():
    all_names = trips[trips['Checkout Kiosk ID']==checkout_id]['Checkout Kiosk'].unique()
    nnames.append(len(all_names))

    if len(all_names) >2:
        print("Kiosk ID - ", checkout_id)
        print(len(all_names),": ", all_names, "\n")

# %% [markdown]
# 2. RETURN KIOSK IDS

# %%
nnames = []
for return_id in trips['Return Kiosk ID'].unique():
    all_names = trips[trips['Return Kiosk ID']==return_id]['Return Kiosk'].unique()
    nnames.append(len(all_names))

    if len(all_names) == 2 and similar(all_names[0],all_names[1]) < 0.50:
        print("Kiosk ID - ", return_id)
        print(len(all_names),": ", all_names)        
        print("ratio: ", round(similar(all_names[0],all_names[1]),4),"\n")

# %%
nnames = []
for return_id in trips['Return Kiosk ID'].unique():
    all_names = trips[trips['Return Kiosk ID']==return_id]['Return Kiosk'].unique()
    nnames.append(len(all_names))

    if len(all_names) >2:
        print("Kiosk ID - ", return_id)
        print(len(all_names),": ", all_names, "\n")

# %%
kiosk.loc[kiosk["Kiosk ID"]==7187]
# Out:
#     Kiosk ID           Kiosk Name Kiosk Status                 Location  \
# 82      7187  South Congress/Mary       active  (30.244961, -97.751272)
#
#                      Address Alternate Name City Asset Number  \
# 82  1901 South Congress Ave.            NaN               0.0
#
#            Property Type Number of Docks Power Type Footprint Length  \
# 82  undetermined_parking            11.0      solar             40.0
#
#    Footprint Width          Notes  Council District Image  \
# 82            10.0  In the gutter                 9   NaN
#
#              Modified Date
# 82  03/04/2022 09:01:00 AM

# %%
trips['Return Kiosk ID'].isnull().value_counts()
# Out:
# False    1823549
# True        2003
# Name: Return Kiosk ID, dtype: int64

# %% [markdown]
# A. Check out Kiosk IDs that are missing

# %%
trips['Checkout Kiosk ID'].isnull().value_counts()
# Out:
# False    1823744
# True        1808
# Name: Checkout Kiosk ID, dtype: int64

# %%
#trips.loc[trips["Checkout Kiosk"]==1001]

# %%
kiosk.loc[kiosk["Kiosk Name"].str.contains("Main")]
# Out:
#     Kiosk ID               Kiosk Name Kiosk Status               Location  \
# 41      1001  OFFICE/Main/Shop/Repair       closed  (30.27186, -97.73997)
#
#         Address Alternate Name City Asset Number Property Type  \
# 41  1000 Brazos            NaN               NaN
#
#    Number of Docks Power Type Footprint Length Footprint Width  \
# 41             NaN                         NaN             NaN
#
#                                                 Notes  Council District Image  \
# 41  This is the testing dock/station located at BS...                 1   NaN
#
#              Modified Date
# 41  03/04/2022 09:58:00 AM

# %%
for x in trips.loc[trips['Checkout Kiosk ID'].isnull(),'Checkout Kiosk'].unique():
    print(x)
# Out:
# Mobile Station
# Mobile Station @ Bike Fest
# Marketing Event
# MapJam at Hops & Grain Brewery
# MapJam at Pan Am Park
# MapJam at French Legation
# MapJam at Scoot Inn
# Mobile Station @ Boardwalk Opening Ceremony
# Mobile Station @ Unplugged
# Eeyore's 2017
# Eeyore's 2018
# Springfest 2022

# %%
for x in trips.loc[trips['Return Kiosk ID'].isnull(),'Return Kiosk'].unique():
    print(x)
# Out:
# Main Office
# Customer Service
# Stolen
# Repair Shop
# Shop
# Missing
# MapJam at French Legation
# Mobile Station
# Mobile Station @ Bike Fest
# MapJam at Hops & Grain Brewery
# MapJam at Pan Am Park
# MapJam at Scoot Inn
# Mobile Station @ Boardwalk Opening Ceremony
# Marketing Event
# Mobile Station @ Unplugged
# Main Shop
# Fantasy Zilker
# Eeyore's 2017
# Earth Day ATX 2017
# ACL 2019 Drop Off
# Springfest 2022

# %%
kiosk.loc[kiosk["Kiosk Name"].str.contains("Main")]
# Out:
#     Kiosk ID               Kiosk Name Kiosk Status               Location  \
# 41      1001  OFFICE/Main/Shop/Repair       closed  (30.27186, -97.73997)
#
#         Address Alternate Name City Asset Number Property Type  \
# 41  1000 Brazos            NaN               NaN
#
#    Number of Docks Power Type Footprint Length Footprint Width  \
# 41             NaN                         NaN             NaN
#
#                                                 Notes  Council District Image  \
# 41  This is the testing dock/station located at BS...                 1   NaN
#
#              Modified Date
# 41  03/04/2022 09:58:00 AM

# %%
# Update these in the trips dataset to be the 'OFFICE/Main/Shop/Repair' kiosk
trips.loc[trips['Return Kiosk'] == 'Main Office', 'Return Kiosk ID'] = 1001
trips.loc[trips['Return Kiosk'] == 'Customer Service', 'Return Kiosk ID'] = 1001
trips.loc[trips['Return Kiosk'] == 'Repair Shop', 'Return Kiosk ID'] = 1001
trips.loc[trips['Return Kiosk'] == 'Shop', 'Return Kiosk ID'] = 1001

# %%
for x in trips.loc[trips['Return Kiosk ID'].isnull(),'Return Kiosk'].unique():
    print(x)
# Out:
# Stolen
# Missing
# MapJam at French Legation
# Mobile Station
# Mobile Station @ Bike Fest
# MapJam at Hops & Grain Brewery
# MapJam at Pan Am Park
# MapJam at Scoot Inn
# Mobile Station @ Boardwalk Opening Ceremony
# Marketing Event
# Mobile Station @ Unplugged
# Main Shop
# Fantasy Zilker
# Eeyore's 2017
# Earth Day ATX 2017
# ACL 2019 Drop Off
# Springfest 2022

# %% [markdown]
# # Save cleaned data into CSV files

# %%
trips.to_csv('../Data/trips0.csv')
kiosk.to_csv('../Data/kiosk0.csv')

# %%
trips.head()
# Out:
#       Trip ID                     Membership Type Bicycle ID  Bike Type  \
# 0  9900285854        Annual (San Antonio B-cycle)      207.0        NaN
# 1  9900285855      24-Hour Kiosk (Austin B-cycle)      969.0        NaN
# 2  9900285856  Annual Membership (Austin B-cycle)      214.0        NaN
# 3  9900285857      24-Hour Kiosk (Austin B-cycle)      745.0        NaN
# 4  9900285858      24-Hour Kiosk (Austin B-cycle)      164.0        NaN
#
#   Checkout Date Checkout Time  Checkout Kiosk ID  \
# 0    10/26/2014      13:12:00             2537.0
# 1    10/26/2014      13:12:00             2539.0
# 2    10/26/2014      13:12:00             2537.0
# 3    10/26/2014      13:12:00             2574.0
# 4    10/26/2014      13:12:00             2538.0
#
#                         Checkout Kiosk  Return Kiosk ID  \
# 0                             6th/West           2707.0
# 1  3rd/Trinity @ The Convention Center           2566.0
# 2                             6th/West           2496.0
# 3                          Zilker Park           2574.0
# 4      Bullock Museum @ Congress & MLK           2539.0
#
#                                         Return Kiosk  Trip Duration Minutes  \
# 0                                    Rainey/Cummings                     76
# 1  Electric Drive/Sandra Muraida Way @ Pfluger Pe...                     58
# 2                                       8th/Congress                      8
# 3                                        Zilker Park                     28
# 4                3rd/Trinity @ The Convention Center                     15
#
#    Month    Year   Checkout DateTime     Return DateTime
# 0   10.0  2014.0 2014-10-26 13:12:00 2014-10-26 14:28:00
# 1   10.0  2014.0 2014-10-26 13:12:00 2014-10-26 14:10:00
# 2   10.0  2014.0 2014-10-26 13:12:00 2014-10-26 13:20:00
# 3   10.0  2014.0 2014-10-26 13:12:00 2014-10-26 13:40:00
# 4   10.0  2014.0 2014-10-26 13:12:00 2014-10-26 13:27:00
